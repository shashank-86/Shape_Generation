# %%
import sklearn
import numpy as np
import os
import time
import random
from tqdm import tqdm
import pickle
from sklearn.decomposition import PCA

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class Preprocessing():
  def __init__(self, pca_n_components):
    self.pca = PCA(n_components = pca_n_components)

  def kd_tree(self, points, k):
    points = points[points[:, k-1].argsort()]
    k_max = len(points[0])
    l = len(points)
    if l==1:
      return [points[0]]
    elif l == 2:
      return [points[0], points[1]]
    else:
      m = int((len(points)-1)/2)
      sorted_points_left = self.kd_tree(points[:m], (k+1)%k_max)
      sorted_points_right = self.kd_tree(points[m+1:], (k+1)%k_max)
      sorted_points = [points[m]] + sorted_points_left+ sorted_points_right
      return sorted_points

  def get_data(self, folder_path = '/content/drive/MyDrive/preimage_task/shapenet-chairs-pcd'):
    file_list = [os.path.join(folder_path, x) for x in os.listdir(folder_path)]
    point_clouds = []
    sorted_point_clouds = []
    for file_path in tqdm(file_list, ncols = 100):
        f = open(file_path)
        points = f.readlines()[10:]
        points = np.array([[float(x.split(' ')[0]), float(x.split(' ')[1]), float(x.split(' ')[2][:-2])] for x in points])
        sorted_points = self.kd_tree(points, 1)
        point_clouds.append(points)
        sorted_point_clouds.append(np.array(sorted_points))
    point_clouds = np.array(point_clouds)
    sorted_point_clouds = np.array(sorted_point_clouds)
    sorted_point_clouds_2d = sorted_point_clouds.reshape((-1, 3000))
    print(f"Size of point_cloud : {point_clouds.shape}\nSize of sorted kd_tree point cloud : {sorted_point_clouds.shape}\nSize of sorted 2d kd_tree point cloud : {sorted_point_clouds_2d.shape}")
    return point_clouds, sorted_point_clouds, sorted_point_clouds_2d

  def pca_basis_space(self, data):
    self.pca.fit(data)
    return self.pca.components_

  def pca_projections(self, data):
    return self.pca.fit_transform(data)
  
  def reconstruction_error(self, swapped_col, sub_uTu, full_mat_mul, swapped):
    swapped_mean = np.mean(swapped_col, axis = 0)
    matmul_error = np.matmul((swapped_col - swapped_mean), sub_uTu)
    mat_mul = full_mat_mul + matmul_error
    loss = np.sum(np.square(mat_mul - swapped + np.mean(swapped, axis = 0)), axis = 1)
    return loss, matmul_error, mat_mul

  def optimizing_point_ordering(self, sorted_point_clouds_2d, outer_loop_limit = 1000, inner_loop_limit = 10000, save_path = None):
    corrected = sorted_point_clouds_2d.copy()
    sample = {x: [3*x, 3*x+1, 3*x+2] for x in range(0, 1000)}
    u = self.pca_basis_space(corrected)

    for i in range(outer_loop_limit):
      mean = np.mean(corrected, axis = 0)
      uTu = np.matmul(u.transpose(), u)
      full_mat_mul = np.matmul(corrected - mean, uTu)
      min_loss = np.sum(np.square(full_mat_mul + mean  - corrected), axis = 1)
      print(f'iteration = {i}')
      for _ in tqdm(range(inner_loop_limit), ncols = 100):
        idx = np.array([random.sample(sample.keys(), 2)]).reshape((2,))
        idx_6 =  np.append(sample[idx[0]], sample[idx[1]])
        idx_6_rev = np.append(sample[idx[1]], sample[idx[0]])

        swapped_col = corrected[:, idx_6_rev]
        unswapped_col = corrected[:, idx_6]
        swapped = corrected.copy()
        swapped[:, idx_6] = swapped_col
        
        sub_uTu = uTu[idx_6, :] - uTu[idx_6_rev, :]
        loss, matmul_error, mat_mul = self.reconstruction_error(swapped_col, sub_uTu, full_mat_mul, swapped)
        
        c1 = loss>=min_loss
        c2 = loss<min_loss
        min_loss = min_loss*c1  + loss*c2
        c1 = c1.reshape((-1, 1))
        c2 = c2.reshape((-1, 1))
        final_col = unswapped_col*c1 + swapped_col*c2
        corrected[:, idx_6] = final_col
        full_mat_mul = full_mat_mul*c1  + mat_mul*c2

      self.pca.fit(corrected)
      u = self.pca_basis_space(sorted_point_clouds_2d)
      if save_path is not None:
        np.save(save_path, corrected)

    return corrected

# %%
preprocess = Preprocessing(pca_n_components= 100)
point_clouds, sorted_point_clouds, sorted_point_clouds_2d = preprocess.get_data(folder_path = '/content/drive/MyDrive/preimage_task/shapenet-chairs-pcd')
# Out:
# 100%|███████████████████████████████████████████████████████████| 5000/5000 [00:54<00:00, 91.84it/s]
# Size of point_cloud : (5000, 1000, 3)
# Size of sorted kd_tree point cloud : (5000, 1000, 3)
# Size of sorted 2d kd_tree point cloud : (5000, 3000)

# %%
corrected = preprocess.optimizing_point_ordering(sorted_point_clouds_2d)

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
criterion = nn.BCELoss()

# %%
class Generator(nn.Module):
  def __init__(self):
    super().__init__()
    self.layers = nn.Sequential(
        *[nn.Linear(100, 100, bias = True), nn.BatchNorm1d(100), nn.ReLU(inplace=True)]*4, 
        nn.Linear(100, 100, bias = True),
        nn.BatchNorm1d(100),
        nn.Tanh()
        )
  
  def forward(self, x):
    return self.layers(x)

class Discriminator(nn.Module):
  def __init__(self):
    super().__init__()
    self.layer1 = nn.Sequential(nn.Linear(100, 100, bias = True), nn.BatchNorm1d(100), nn.LeakyReLU(0.2,inplace=True))
    self.layer2 = nn.Sequential(nn.Linear(100, 100, bias = True), nn.BatchNorm1d(100), nn.LeakyReLU(0.2,inplace=True))
    self.layer3 = nn.Sequential(nn.Linear(100, 100, bias = True), nn.BatchNorm1d(100), nn.LeakyReLU(0.2,inplace=True))
    self.layer4 = nn.Sequential(nn.Linear(100, 100, bias = True), nn.BatchNorm1d(100), nn.LeakyReLU(0.2,inplace=True))
    self.layer5 = nn.Sequential(nn.Linear(100, 1, bias = True), nn.Sigmoid()) 
  
  def forward(self, x):
    out1 = self.layer1(x)
    out2 = self.layer2(out1)
    out3 = self.layer3(out2)
    out4 = self.layer4(out3)
    out5 = self.layer5(out4)
    return out5, out4, out3, out2, out1

def init_weights(l):
    if isinstance(l, nn.Linear):
      nn.init.normal_(l.weight, 0, 0.02)
    elif  isinstance(l, nn.BatchNorm1d):
      nn.init.normal_(l.weight.data, 1.0, 0.02)
      nn.init.constant_(l.bias.data, 0)


def discriminator_loss(pred, target):
    return criterion(pred, target)

def generator_loss(t_activations, z_activations):
    loss = 0
    for t_act, z_act in zip(t_activations, z_activations):
      loss += (torch.linalg.norm(torch.mean(t_act, 0) - torch.mean(z_act, 0), 2)**2 + torch.linalg.norm(torch.cov(t_act.transpose(0,1)) - torch.cov(z_act.transpose(0,1)), 2)**2)
    return loss


def fake_point_cloud_generator(data, number_of_fake_points = 1000 ,checkpoint_path = None, generator = None):
  if checkpoint_path is not None:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    checkpoint = torch.load(checkpoint_path, map_location = device)
    gen = Generator().to(device)
    gen.load_state_dict(checkpoint['gen_state_dict'])
  else:
    gen = generator

  pca = PCA(n_components = 100)
  pca.fit(data.reshape((-1, 3000)))
  noise = torch.randn((number_of_fake_points,100))*2 - 1
  fake_coeff = gen(noise)
  pc_fake = pca.inverse_transform(fake_coeff.detach().numpy())
  pc_fake = pc_fake.reshape((-1, 1000, 3))

  return pc_fake

def Training(dataset, save_name = None, num_epochs = 1000, checkpoint_path = None):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    pca = PCA(n_components= 100)
    dataset = dataset.reshape((-1, 3000))
    data = pca.fit_transform(dataset)
    data = torch.from_numpy(data).float().to(device)
    
    gen = Generator().to(device)
    dis = Discriminator().to(device)
    optimizer_g = torch.optim.Adam(gen.parameters(), lr = 0.0025)
    optimizer_d = torch.optim.Adam(dis.parameters(), lr = 0.0001)

    if checkpoint_path == None:
      epoch = 1
      gen.apply(init_weights)
      dis.apply(init_weights)
      g_loss = [] 
      d_loss = [] 
      d_acc = [] 
      train_discriminator = True

    else:
      checkpoint = torch.load(checkpoint_path, map_location = torch.device(device))
      epoch = checkpoint['epoch'] + 1
      gen.load_state_dict(checkpoint['gen_state_dict'])
      dis.load_state_dict(checkpoint['dis_state_dict'])
      optimizer_g.load_state_dict(checkpoint['optimizer_g_state_dict'])
      optimizer_d.load_state_dict(checkpoint['optimizer_d_state_dict'])
      g_loss = checkpoint['g_loss']
      d_loss = checkpoint['d_loss']
      d_acc = checkpoint['d_acc']
      train_discriminator = checkpoint['train_discriminator']
  

    while(epoch < num_epochs + 1):

      if train_discriminator:
          #Training discriminator
          dis.zero_grad()
          real_out = dis(data)
          real_label = torch.full_like(real_out[0], 1, device= device)
          real_loss = criterion(real_out[0], real_label)
          noise = torch.randn(data.shape, device = device)*2 - 1
          fake_coeff = gen(noise)
          fake_out = dis(fake_coeff)
          fake_label = torch.full_like(real_label, 0, device = device)
          fake_loss = criterion(fake_out[0], fake_label)
          dis_acc = (torch.sum(fake_out[0] < 0.5) + torch.sum(real_out[0]  > 0.5))*50/real_out[0].shape[0]
          dis_loss = real_loss + fake_loss
          dis_loss.backward()
          optimizer_d.step()


      #Trainig generator
      gen.zero_grad()
      real_out = dis(data)
      noise = torch.randn(data.shape, device = device)*2 - 1
      fake_coeff = gen(noise)
      fake_out = dis(fake_coeff)
      gen_loss = generator_loss(real_out[1:], fake_out[1:])
      gen_loss.backward()
      optimizer_g.step()
    
      g_loss.append(gen_loss) 
      if train_discriminator:
          d_loss.append(dis_loss)
          d_acc.append(dis_acc)

      print("===> Epoch({}/{}): G_Loss: {:.4f} ".format(
        epoch, num_epochs, gen_loss.item()), end = "")
      if train_discriminator:
          print("D_Loss: {:.4f} D_Accuracy: {:.4f}".format(dis_loss.item(), dis_acc.item()), end = "")
      print("")

      if save_name is not None:
        torch.save({
            'epoch' : epoch,
            'num_epochs': num_epochs,
            'gen_state_dict' : gen.state_dict(),
            'dis_state_dict' : dis.state_dict(),
            'optimizer_g_state_dict' : optimizer_g.state_dict(),
            'optimizer_d_state_dict' : optimizer_d.state_dict(),
            'g_loss' : g_loss,
            'd_loss' : d_loss,
            'd_acc' : d_acc,
            'train_discriminator' : train_discriminator
        }, "/content/drive/MyDrive/preimage_task/gans_tanh_init_wt_crr_iter_0/" + save_name + ".pth" )
      
      if torch.mean(torch.tensor(d_acc[-40:])).item() > 90:
        train_discriminator = False

      epoch+=1

    return gen, d_loss, g_loss, d_acc

# %%
loss = y*np.log10(z) + (1-y)*np.log10((1-z))

# %%
gen, d_loss, g_loss, d_acc = Training(corrected, num_epochs = 2500)
# Out:
# ===> Epoch(1/2500): G_Loss: 155.4699 D_Loss: 1.3932 D_Accuracy: 47.3800
# ===> Epoch(2/2500): G_Loss: 97.8572 D_Loss: 1.3909 D_Accuracy: 49.2700
# ===> Epoch(3/2500): G_Loss: 88.0798 D_Loss: 1.3892 D_Accuracy: 49.5900
# ===> Epoch(4/2500): G_Loss: 63.5626 D_Loss: 1.3883 D_Accuracy: 50.1700
# ===> Epoch(5/2500): G_Loss: 65.9803 D_Loss: 1.3867 D_Accuracy: 50.9300
# ===> Epoch(6/2500): G_Loss: 64.8966 D_Loss: 1.3854 D_Accuracy: 51.3400
# ===> Epoch(7/2500): G_Loss: 57.7458 D_Loss: 1.3842 D_Accuracy: 52.5600
# ===> Epoch(8/2500): G_Loss: 48.5564 D_Loss: 1.3832 D_Accuracy: 52.8000
# ===> Epoch(9/2500): G_Loss: 44.3228 D_Loss: 1.3823 D_Accuracy: 53.8300
# ===> Epoch(10/2500): G_Loss: 44.6065 D_Loss: 1.3813 D_Accuracy: 54.0600
# ===> Epoch(11/2500): G_Loss: 37.1304 D_Loss: 1.3805 D_Accuracy: 54.6900
# ===> Epoch(12/2500): G_Loss: 37.5032 D_Loss: 1.3798 D_Accuracy: 54.8300
# ===> Epoch(13/2500): G_Loss: 39.9722 D_Loss: 1.3790 D_Accuracy: 55.0400
# ===> Epoch(14/2500): G_Loss: 36.1717 D_Loss: 1.3782 D_Accuracy: 55.5000
# ===> Epoch(15/2500): G_Loss: 36.9630 D_Loss: 1.3774 D_Accuracy: 55.9300
# ===> Epoch(16/2500): G_Loss: 31.2690 D_Loss: 1.3766 D_Accuracy: 56.4900
# ===> Epoch(17/2500): G_Loss: 30.6363 D_Loss: 1.3755 D_Accuracy: 57.3500
# ===> Epoch(18/2500): G_Loss: 29.4233 D_Loss: 1.3746 D_Accuracy: 57.9800
# ===> Epoch(19/2500): G_Loss: 28.1154 D_Loss: 1.3737 D_Accuracy: 58.5600
# ===> Epoch(20/2500): G_Loss: 26.7551 D_Loss: 1.3731 D_Accuracy: 58.6500
# ===> Epoch(21/2500): G_Loss: 26.3266 D_Loss: 1.3722 D_Accuracy: 60.0100
# ===> Epoch(22/2500): G_Loss: 25.9741 D_Loss: 1.3713 D_Accuracy: 60.1700
# ===> Epoch(23/2500): G_Loss: 25.0371 D_Loss: 1.3704 D_Accuracy: 60.8100
# ===> Epoch(24/2500): G_Loss: 24.8617 D_Loss: 1.3697 D_Accuracy: 61.1900
# ===> Epoch(25/2500): G_Loss: 25.0490 D_Loss: 1.3685 D_Accuracy: 62.1500
# ===> Epoch(26/2500): G_Loss: 23.9435 D_Loss: 1.3675 D_Accuracy: 62.6400
# ===> Epoch(27/2500): G_Loss: 24.8511 D_Loss: 1.3670 D_Accuracy: 62.8300
# ===> Epoch(28/2500): G_Loss: 25.8297 D_Loss: 1.3659 D_Accuracy: 63.7200
# ===> Epoch(29/2500): G_Loss: 25.8852 D_Loss: 1.3648 D_Accuracy: 64.2500
# ===> Epoch(30/2500): G_Loss: 23.7577 D_Loss: 1.3638 D_Accuracy: 65.0000
# ===> Epoch(31/2500): G_Loss: 24.1081 D_Loss: 1.3629 D_Accuracy: 65.5100
# ===> Epoch(32/2500): G_Loss: 23.3686 D_Loss: 1.3620 D_Accuracy: 65.9100
# ===> Epoch(33/2500): G_Loss: 23.5549 D_Loss: 1.3607 D_Accuracy: 66.4900
# ===> Epoch(34/2500): G_Loss: 23.4303 D_Loss: 1.3600 D_Accuracy: 67.1500
# ===> Epoch(35/2500): G_Loss: 24.4286 D_Loss: 1.3590 D_Accuracy: 67.7900
# ===> Epoch(36/2500): G_Loss: 25.3505 D_Loss: 1.3580 D_Accuracy: 68.1800
# ===> Epoch(37/2500): G_Loss: 24.3927 D_Loss: 1.3568 D_Accuracy: 68.4000
# ===> Epoch(38/2500): G_Loss: 24.5320 D_Loss: 1.3553 D_Accuracy: 69.4200
# ===> Epoch(39/2500): G_Loss: 25.1895 D_Loss: 1.3544 D_Accuracy: 69.1600
# ===> Epoch(40/2500): G_Loss: 26.2547 D_Loss: 1.3533 D_Accuracy: 69.6900
# ===> Epoch(41/2500): G_Loss: 24.5661 D_Loss: 1.3527 D_Accuracy: 69.7800
# ===> Epoch(42/2500): G_Loss: 25.2950 D_Loss: 1.3515 D_Accuracy: 70.3500
# ===> Epoch(43/2500): G_Loss: 25.3747 D_Loss: 1.3504 D_Accuracy: 70.6900
# ===> Epoch(44/2500): G_Loss: 27.0122 D_Loss: 1.3493 D_Accuracy: 70.5600
# ===> Epoch(45/2500): G_Loss: 27.6151 D_Loss: 1.3483 D_Accuracy: 70.9400
# ===> Epoch(46/2500): G_Loss: 27.9535 D_Loss: 1.3468 D_Accuracy: 71.5900
# ===> Epoch(47/2500): G_Loss: 28.1621 D_Loss: 1.3461 D_Accuracy: 71.5100
# ===> Epoch(48/2500): G_Loss: 28.1326 D_Loss: 1.3445 D_Accuracy: 72.4300
# ===> Epoch(49/2500): G_Loss: 29.0997 D_Loss: 1.3429 D_Accuracy: 72.8700
# ===> Epoch(50/2500): G_Loss: 28.7866 D_Loss: 1.3417 D_Accuracy: 73.5800
# ===> Epoch(51/2500): G_Loss: 30.0528 D_Loss: 1.3408 D_Accuracy: 73.7300
# ===> Epoch(52/2500): G_Loss: 31.2557 D_Loss: 1.3398 D_Accuracy: 74.1600
# ===> Epoch(53/2500): G_Loss: 30.0244 D_Loss: 1.3375 D_Accuracy: 74.6300
# ===> Epoch(54/2500): G_Loss: 29.8198 D_Loss: 1.3371 D_Accuracy: 74.9000
# ===> Epoch(55/2500): G_Loss: 30.0901 D_Loss: 1.3353 D_Accuracy: 75.8100
# ===> Epoch(56/2500): G_Loss: 30.4065 D_Loss: 1.3350 D_Accuracy: 75.7200
# ===> Epoch(57/2500): G_Loss: 32.4297 D_Loss: 1.3340 D_Accuracy: 76.1700
# ===> Epoch(58/2500): G_Loss: 32.1600 D_Loss: 1.3319 D_Accuracy: 76.9800
# ===> Epoch(59/2500): G_Loss: 34.7080 D_Loss: 1.3313 D_Accuracy: 77.5100
# ===> Epoch(60/2500): G_Loss: 35.1471 D_Loss: 1.3313 D_Accuracy: 77.5200
# ===> Epoch(61/2500): G_Loss: 35.9275 D_Loss: 1.3300 D_Accuracy: 78.0900
# ===> Epoch(62/2500): G_Loss: 34.5370 D_Loss: 1.3278 D_Accuracy: 78.8500
# ===> Epoch(63/2500): G_Loss: 33.7863 D_Loss: 1.3261 D_Accuracy: 78.9200
# ===> Epoch(64/2500): G_Loss: 36.2621 D_Loss: 1.3244 D_Accuracy: 80.0100
# ===> Epoch(65/2500): G_Loss: 37.1600 D_Loss: 1.3237 D_Accuracy: 80.0500
# ===> Epoch(66/2500): G_Loss: 37.5396 D_Loss: 1.3230 D_Accuracy: 79.9300
# ===> Epoch(67/2500): G_Loss: 37.4183 D_Loss: 1.3221 D_Accuracy: 80.2200
# ===> Epoch(68/2500): G_Loss: 38.4246 D_Loss: 1.3214 D_Accuracy: 80.1800
# ===> Epoch(69/2500): G_Loss: 38.3267 D_Loss: 1.3202 D_Accuracy: 80.2600
# ===> Epoch(70/2500): G_Loss: 39.6068 D_Loss: 1.3195 D_Accuracy: 80.3000
# ===> Epoch(71/2500): G_Loss: 42.9680 D_Loss: 1.3198 D_Accuracy: 80.3700
# ===> Epoch(72/2500): G_Loss: 42.0459 D_Loss: 1.3162 D_Accuracy: 81.1600
# ===> Epoch(73/2500): G_Loss: 42.9318 D_Loss: 1.3148 D_Accuracy: 81.1000
# ===> Epoch(74/2500): G_Loss: 42.9025 D_Loss: 1.3134 D_Accuracy: 81.2300
# ===> Epoch(75/2500): G_Loss: 42.7468 D_Loss: 1.3107 D_Accuracy: 81.7600
# ===> Epoch(76/2500): G_Loss: 46.0361 D_Loss: 1.3094 D_Accuracy: 82.2300
# ===> Epoch(77/2500): G_Loss: 41.0718 D_Loss: 1.3077 D_Accuracy: 82.7600
# ===> Epoch(78/2500): G_Loss: 44.9700 D_Loss: 1.3074 D_Accuracy: 83.2800
# ===> Epoch(79/2500): G_Loss: 44.0885 D_Loss: 1.3061 D_Accuracy: 83.5700
# ===> Epoch(80/2500): G_Loss: 46.3650 D_Loss: 1.3047 D_Accuracy: 83.6900
# ===> Epoch(81/2500): G_Loss: 46.7722 D_Loss: 1.3029 D_Accuracy: 84.1900
# ===> Epoch(82/2500): G_Loss: 47.1067 D_Loss: 1.3004 D_Accuracy: 84.6600
# ===> Epoch(83/2500): G_Loss: 47.8671 D_Loss: 1.2997 D_Accuracy: 84.7100
# ===> Epoch(84/2500): G_Loss: 46.9365 D_Loss: 1.2997 D_Accuracy: 84.9300
# ===> Epoch(85/2500): G_Loss: 48.8546 D_Loss: 1.2965 D_Accuracy: 85.2500
# ===> Epoch(86/2500): G_Loss: 49.9772 D_Loss: 1.2965 D_Accuracy: 84.5600
# ===> Epoch(87/2500): G_Loss: 47.1609 D_Loss: 1.2945 D_Accuracy: 84.4100
# ===> Epoch(88/2500): G_Loss: 52.2524 D_Loss: 1.2916 D_Accuracy: 85.2300
# ===> Epoch(89/2500): G_Loss: 60.1818 D_Loss: 1.2882 D_Accuracy: 85.9600
# ===> Epoch(90/2500): G_Loss: 55.6865 D_Loss: 1.2896 D_Accuracy: 83.9700
# ===> Epoch(91/2500): G_Loss: 63.0324 D_Loss: 1.2915 D_Accuracy: 82.5900
# ===> Epoch(92/2500): G_Loss: 61.3963 D_Loss: 1.2895 D_Accuracy: 83.1400
# ===> Epoch(93/2500): G_Loss: 59.1231 D_Loss: 1.2873 D_Accuracy: 83.8300
# ===> Epoch(94/2500): G_Loss: 67.0135 D_Loss: 1.2848 D_Accuracy: 84.5800
# ===> Epoch(95/2500): G_Loss: 58.3416 D_Loss: 1.2846 D_Accuracy: 84.1500
# ===> Epoch(96/2500): G_Loss: 55.7623 D_Loss: 1.2841 D_Accuracy: 84.2600
# ===> Epoch(97/2500): G_Loss: 57.3170 D_Loss: 1.2813 D_Accuracy: 85.3800
# ===> Epoch(98/2500): G_Loss: 57.2610 D_Loss: 1.2791 D_Accuracy: 86.0900
# ===> Epoch(99/2500): G_Loss: 57.7594 D_Loss: 1.2778 D_Accuracy: 85.9500
# ===> Epoch(100/2500): G_Loss: 59.0775 D_Loss: 1.2765 D_Accuracy: 86.4600
# ===> Epoch(101/2500): G_Loss: 58.8697 D_Loss: 1.2740 D_Accuracy: 86.6100
# ===> Epoch(102/2500): G_Loss: 57.5590 D_Loss: 1.2725 D_Accuracy: 86.8700
# ===> Epoch(103/2500): G_Loss: 58.4176 D_Loss: 1.2706 D_Accuracy: 87.2200
# ===> Epoch(104/2500): G_Loss: 63.6505 D_Loss: 1.2692 D_Accuracy: 87.2900
# ===> Epoch(105/2500): G_Loss: 56.4747 D_Loss: 1.2687 D_Accuracy: 87.1800
# ===> Epoch(106/2500): G_Loss: 59.6774 D_Loss: 1.2690 D_Accuracy: 86.2800
# ===> Epoch(107/2500): G_Loss: 62.3951 D_Loss: 1.2697 D_Accuracy: 85.5700
# ===> Epoch(108/2500): G_Loss: 62.1613 D_Loss: 1.2700 D_Accuracy: 85.2600
# ===> Epoch(109/2500): G_Loss: 63.5323 D_Loss: 1.2672 D_Accuracy: 85.7700
# ===> Epoch(110/2500): G_Loss: 62.1842 D_Loss: 1.2632 D_Accuracy: 86.8800
# ===> Epoch(111/2500): G_Loss: 60.9717 D_Loss: 1.2600 D_Accuracy: 87.5600
# ===> Epoch(112/2500): G_Loss: 66.6923 D_Loss: 1.2586 D_Accuracy: 87.8500
# ===> Epoch(113/2500): G_Loss: 62.4585 D_Loss: 1.2574 D_Accuracy: 86.7600
# ===> Epoch(114/2500): G_Loss: 64.2152 D_Loss: 1.2567 D_Accuracy: 86.0400
# ===> Epoch(115/2500): G_Loss: 64.3533 D_Loss: 1.2559 D_Accuracy: 86.0800
# ===> Epoch(116/2500): G_Loss: 61.7357 D_Loss: 1.2548 D_Accuracy: 86.5000
# ===> Epoch(117/2500): G_Loss: 64.1467 D_Loss: 1.2542 D_Accuracy: 86.7300
# ===> Epoch(118/2500): G_Loss: 67.0959 D_Loss: 1.2546 D_Accuracy: 86.7800
# ===> Epoch(119/2500): G_Loss: 63.6933 D_Loss: 1.2543 D_Accuracy: 86.2500
# ===> Epoch(120/2500): G_Loss: 64.6254 D_Loss: 1.2529 D_Accuracy: 86.1700
# ===> Epoch(121/2500): G_Loss: 66.4335 D_Loss: 1.2485 D_Accuracy: 87.3400
# ===> Epoch(122/2500): G_Loss: 66.9704 D_Loss: 1.2466 D_Accuracy: 88.4500
# ===> Epoch(123/2500): G_Loss: 65.7268 D_Loss: 1.2444 D_Accuracy: 89.3200
# ===> Epoch(124/2500): G_Loss: 64.8762 D_Loss: 1.2442 D_Accuracy: 89.4700
# ===> Epoch(125/2500): G_Loss: 64.3289 D_Loss: 1.2439 D_Accuracy: 89.6700
# ===> Epoch(126/2500): G_Loss: 63.1246 D_Loss: 1.2461 D_Accuracy: 88.3300
# ===> Epoch(127/2500): G_Loss: 64.9018 D_Loss: 1.2458 D_Accuracy: 87.5500
# ===> Epoch(128/2500): G_Loss: 71.0421 D_Loss: 1.2438 D_Accuracy: 87.3700
# ===> Epoch(129/2500): G_Loss: 66.9583 D_Loss: 1.2427 D_Accuracy: 87.6100
# ===> Epoch(130/2500): G_Loss: 67.7455 D_Loss: 1.2400 D_Accuracy: 88.9500
# ===> Epoch(131/2500): G_Loss: 70.9789 D_Loss: 1.2443 D_Accuracy: 87.7400
# ===> Epoch(132/2500): G_Loss: 70.6577 D_Loss: 1.2426 D_Accuracy: 88.0500
# ===> Epoch(133/2500): G_Loss: 69.1775 D_Loss: 1.2426 D_Accuracy: 87.6300
# ===> Epoch(134/2500): G_Loss: 79.8766 D_Loss: 1.2400 D_Accuracy: 88.8900
# ===> Epoch(135/2500): G_Loss: 76.4631 D_Loss: 1.2414 D_Accuracy: 88.1700
# ===> Epoch(136/2500): G_Loss: 81.7764 D_Loss: 1.2391 D_Accuracy: 87.8500
# ===> Epoch(137/2500): G_Loss: 76.9790 D_Loss: 1.2358 D_Accuracy: 88.5500
# ===> Epoch(138/2500): G_Loss: 77.0584 D_Loss: 1.2303 D_Accuracy: 89.1500
# ===> Epoch(139/2500): G_Loss: 92.7602 D_Loss: 1.2275 D_Accuracy: 89.4700
# ===> Epoch(140/2500): G_Loss: 77.7145 D_Loss: 1.2242 D_Accuracy: 89.8100
# ===> Epoch(141/2500): G_Loss: 92.8691 D_Loss: 1.2221 D_Accuracy: 89.6300
# ===> Epoch(142/2500): G_Loss: 87.6890 D_Loss: 1.2228 D_Accuracy: 89.2700
# ===> Epoch(143/2500): G_Loss: 83.7867 D_Loss: 1.2240 D_Accuracy: 89.0900
# ===> Epoch(144/2500): G_Loss: 84.1783 D_Loss: 1.2241 D_Accuracy: 89.6100
# ===> Epoch(145/2500): G_Loss: 87.3943 D_Loss: 1.2227 D_Accuracy: 89.5600
# ===> Epoch(146/2500): G_Loss: 86.7193 D_Loss: 1.2185 D_Accuracy: 89.8300
# ===> Epoch(147/2500): G_Loss: 91.3619 D_Loss: 1.2161 D_Accuracy: 89.3900
# ===> Epoch(148/2500): G_Loss: 87.3969 D_Loss: 1.2165 D_Accuracy: 89.3700
# ===> Epoch(149/2500): G_Loss: 90.2432 D_Loss: 1.2187 D_Accuracy: 89.7100
# ===> Epoch(150/2500): G_Loss: 91.5696 D_Loss: 1.2184 D_Accuracy: 89.4300
# ===> Epoch(151/2500): G_Loss: 88.5969 D_Loss: 1.2150 D_Accuracy: 89.8200
# ===> Epoch(152/2500): G_Loss: 90.0489 D_Loss: 1.2106 D_Accuracy: 90.5100
# ===> Epoch(153/2500): G_Loss: 87.2674 D_Loss: 1.2074 D_Accuracy: 90.6600
# ===> Epoch(154/2500): G_Loss: 88.4061 D_Loss: 1.2037 D_Accuracy: 91.2500
# ===> Epoch(155/2500): G_Loss: 89.6783 D_Loss: 1.2065 D_Accuracy: 90.2000
# ===> Epoch(156/2500): G_Loss: 85.5465 D_Loss: 1.2067 D_Accuracy: 89.7800
# ===> Epoch(157/2500): G_Loss: 87.1379 D_Loss: 1.2059 D_Accuracy: 89.5100
# ===> Epoch(158/2500): G_Loss: 86.8123 D_Loss: 1.2037 D_Accuracy: 90.0400
# ===> Epoch(159/2500): G_Loss: 84.7735 D_Loss: 1.2003 D_Accuracy: 90.2500
# ===> Epoch(160/2500): G_Loss: 89.5508 D_Loss: 1.1996 D_Accuracy: 89.8100
# ===> Epoch(161/2500): G_Loss: 84.5719 D_Loss: 1.2011 D_Accuracy: 89.6500
# ===> Epoch(162/2500): G_Loss: 82.4453 D_Loss: 1.2024 D_Accuracy: 89.4600
# ===> Epoch(163/2500): G_Loss: 80.1350 D_Loss: 1.2011 D_Accuracy: 89.6000
# ===> Epoch(164/2500): G_Loss: 89.3638 D_Loss: 1.2011 D_Accuracy: 89.3300
# ===> Epoch(165/2500): G_Loss: 81.0435 D_Loss: 1.1962 D_Accuracy: 90.0900
# ===> Epoch(166/2500): G_Loss: 102.0891 D_Loss: 1.1888 D_Accuracy: 90.6200
# ===> Epoch(167/2500): G_Loss: 86.8644 D_Loss: 1.1880 D_Accuracy: 90.7200
# ===> Epoch(168/2500): G_Loss: 98.3453 D_Loss: 1.1928 D_Accuracy: 89.6200
# ===> Epoch(169/2500): G_Loss: 94.6190 D_Loss: 1.1942 D_Accuracy: 89.4900
# ===> Epoch(170/2500): G_Loss: 94.6742 D_Loss: 1.1902 D_Accuracy: 89.8300
# ===> Epoch(171/2500): G_Loss: 92.4434 D_Loss: 1.1871 D_Accuracy: 89.7300
# ===> Epoch(172/2500): G_Loss: 94.3830 D_Loss: 1.1861 D_Accuracy: 89.6900
# ===> Epoch(173/2500): G_Loss: 91.3734 D_Loss: 1.1849 D_Accuracy: 90.0400
# ===> Epoch(174/2500): G_Loss: 95.1590 D_Loss: 1.1846 D_Accuracy: 89.9200
# ===> Epoch(175/2500): G_Loss: 103.5419 D_Loss: 1.1816 D_Accuracy: 90.6900
# ===> Epoch(176/2500): G_Loss: 100.2439 D_Loss: 1.1817 D_Accuracy: 91.1700
# ===> Epoch(177/2500): G_Loss: 98.4867 D_Loss: 1.1829 D_Accuracy: 91.3200
# ===> Epoch(178/2500): G_Loss: 98.1129 D_Loss: 1.1803 D_Accuracy: 91.0600
# ===> Epoch(179/2500): G_Loss: 99.4537 D_Loss: 1.1788 D_Accuracy: 90.9900
# ===> Epoch(180/2500): G_Loss: 99.8062 D_Loss: 1.1775 D_Accuracy: 91.2500
# ===> Epoch(181/2500): G_Loss: 92.2532
# ===> Epoch(182/2500): G_Loss: 90.9946
# ===> Epoch(183/2500): G_Loss: 82.5452
# ===> Epoch(184/2500): G_Loss: 79.7325
# ===> Epoch(185/2500): G_Loss: 69.6444
# ===> Epoch(186/2500): G_Loss: 66.6250
# ===> Epoch(187/2500): G_Loss: 63.0284
# ===> Epoch(188/2500): G_Loss: 60.1336
# ===> Epoch(189/2500): G_Loss: 57.9579
# ===> Epoch(190/2500): G_Loss: 55.8513
# ===> Epoch(191/2500): G_Loss: 55.1638
# ===> Epoch(192/2500): G_Loss: 55.0647
# ===> Epoch(193/2500): G_Loss: 51.9125
# ===> Epoch(194/2500): G_Loss: 48.5246
# ===> Epoch(195/2500): G_Loss: 46.9226
# ===> Epoch(196/2500): G_Loss: 44.0653
# ===> Epoch(197/2500): G_Loss: 43.0110
# ===> Epoch(198/2500): G_Loss: 43.3306
# ===> Epoch(199/2500): G_Loss: 39.2919
# ===> Epoch(200/2500): G_Loss: 38.5928
# ===> Epoch(201/2500): G_Loss: 36.9262
# ===> Epoch(202/2500): G_Loss: 36.6537
# ===> Epoch(203/2500): G_Loss: 34.7990
# ===> Epoch(204/2500): G_Loss: 34.3538
# ===> Epoch(205/2500): G_Loss: 33.4782
# ===> Epoch(206/2500): G_Loss: 30.7273
# ===> Epoch(207/2500): G_Loss: 30.8211
# ===> Epoch(208/2500): G_Loss: 30.3574
# ===> Epoch(209/2500): G_Loss: 29.8462
# ===> Epoch(210/2500): G_Loss: 31.7431
# ===> Epoch(211/2500): G_Loss: 32.0471
# ===> Epoch(212/2500): G_Loss: 27.0370
# ===> Epoch(213/2500): G_Loss: 26.1798
# ===> Epoch(214/2500): G_Loss: 27.2079
# ===> Epoch(215/2500): G_Loss: 26.1129
# ===> Epoch(216/2500): G_Loss: 26.4887
# ===> Epoch(217/2500): G_Loss: 27.5993
# ===> Epoch(218/2500): G_Loss: 24.7789
# ===> Epoch(219/2500): G_Loss: 25.2696
# ===> Epoch(220/2500): G_Loss: 24.4189
# ===> Epoch(221/2500): G_Loss: 24.1983
# ===> Epoch(222/2500): G_Loss: 23.5086
# ===> Epoch(223/2500): G_Loss: 29.3214
# ===> Epoch(224/2500): G_Loss: 22.8469
# ===> Epoch(225/2500): G_Loss: 22.3380
# ===> Epoch(226/2500): G_Loss: 23.5857
# ===> Epoch(227/2500): G_Loss: 20.3252
# ===> Epoch(228/2500): G_Loss: 20.2495
# ===> Epoch(229/2500): G_Loss: 20.4943
# ===> Epoch(230/2500): G_Loss: 20.2178
# ===> Epoch(231/2500): G_Loss: 19.3007
# ===> Epoch(232/2500): G_Loss: 20.4476
# ===> Epoch(233/2500): G_Loss: 18.7056
# ===> Epoch(234/2500): G_Loss: 18.4453
# ===> Epoch(235/2500): G_Loss: 19.1566
# ===> Epoch(236/2500): G_Loss: 19.9688
# ===> Epoch(237/2500): G_Loss: 18.7100
# ===> Epoch(238/2500): G_Loss: 21.3782
# ===> Epoch(239/2500): G_Loss: 17.2877
# ===> Epoch(240/2500): G_Loss: 15.4834
# ===> Epoch(241/2500): G_Loss: 15.9827
# ===> Epoch(242/2500): G_Loss: 17.7177
# ===> Epoch(243/2500): G_Loss: 17.8897
# ===> Epoch(244/2500): G_Loss: 17.6788
# ===> Epoch(245/2500): G_Loss: 16.6947
# ===> Epoch(246/2500): G_Loss: 17.5973
# ===> Epoch(247/2500): G_Loss: 14.9068
# ===> Epoch(248/2500): G_Loss: 16.6436
# ===> Epoch(249/2500): G_Loss: 14.9477
# ===> Epoch(250/2500): G_Loss: 15.9573
# ===> Epoch(251/2500): G_Loss: 15.1176
# ===> Epoch(252/2500): G_Loss: 14.6763
# ===> Epoch(253/2500): G_Loss: 16.3715
# ===> Epoch(254/2500): G_Loss: 13.5192
# ===> Epoch(255/2500): G_Loss: 13.8794
# ===> Epoch(256/2500): G_Loss: 19.6975
# ===> Epoch(257/2500): G_Loss: 13.1459
# ===> Epoch(258/2500): G_Loss: 13.2619
# ===> Epoch(259/2500): G_Loss: 14.7034
# ===> Epoch(260/2500): G_Loss: 15.5992
# ===> Epoch(261/2500): G_Loss: 13.5014
# ===> Epoch(262/2500): G_Loss: 14.7473
# ===> Epoch(263/2500): G_Loss: 13.8711
# ===> Epoch(264/2500): G_Loss: 13.0871
# ===> Epoch(265/2500): G_Loss: 13.1555
# ===> Epoch(266/2500): G_Loss: 12.8136
# ===> Epoch(267/2500): G_Loss: 13.2000
# ===> Epoch(268/2500): G_Loss: 12.7045
# ===> Epoch(269/2500): G_Loss: 12.2073
# ===> Epoch(270/2500): G_Loss: 11.9218
# ===> Epoch(271/2500): G_Loss: 12.7269
# ===> Epoch(272/2500): G_Loss: 12.5236
# ===> Epoch(273/2500): G_Loss: 12.6312
# ===> Epoch(274/2500): G_Loss: 13.7776
# ===> Epoch(275/2500): G_Loss: 11.3398
# ===> Epoch(276/2500): G_Loss: 12.1191
# ===> Epoch(277/2500): G_Loss: 11.9539
# ===> Epoch(278/2500): G_Loss: 11.1049
# ===> Epoch(279/2500): G_Loss: 11.3816
# ===> Epoch(280/2500): G_Loss: 10.7762
# ===> Epoch(281/2500): G_Loss: 10.4421
# ===> Epoch(282/2500): G_Loss: 12.4445
# ===> Epoch(283/2500): G_Loss: 10.7864
# ===> Epoch(284/2500): G_Loss: 10.3513
# ===> Epoch(285/2500): G_Loss: 13.5200
# ===> Epoch(286/2500): G_Loss: 10.7752
# ===> Epoch(287/2500): G_Loss: 11.8248
# ===> Epoch(288/2500): G_Loss: 15.9130
# ===> Epoch(289/2500): G_Loss: 13.6979
# ===> Epoch(290/2500): G_Loss: 13.2256
# ===> Epoch(291/2500): G_Loss: 12.2765
# ===> Epoch(292/2500): G_Loss: 12.3182
# ===> Epoch(293/2500): G_Loss: 10.3092
# ===> Epoch(294/2500): G_Loss: 12.7724
# ===> Epoch(295/2500): G_Loss: 14.0578
# ===> Epoch(296/2500): G_Loss: 10.5407
# ===> Epoch(297/2500): G_Loss: 12.5398
# ===> Epoch(298/2500): G_Loss: 11.7246
# ===> Epoch(299/2500): G_Loss: 12.4585
# ===> Epoch(300/2500): G_Loss: 10.3347
# ===> Epoch(301/2500): G_Loss: 15.6744
# ===> Epoch(302/2500): G_Loss: 10.9351
# ===> Epoch(303/2500): G_Loss: 10.3164
# ===> Epoch(304/2500): G_Loss: 10.0586
# ===> Epoch(305/2500): G_Loss: 11.5296
# ===> Epoch(306/2500): G_Loss: 10.7824
# ===> Epoch(307/2500): G_Loss: 10.7049
# ===> Epoch(308/2500): G_Loss: 9.0776
# ===> Epoch(309/2500): G_Loss: 9.7682
# ===> Epoch(310/2500): G_Loss: 9.4491
# ===> Epoch(311/2500): G_Loss: 8.3020
# ===> Epoch(312/2500): G_Loss: 8.5602
# ===> Epoch(313/2500): G_Loss: 9.2541
# ===> Epoch(314/2500): G_Loss: 9.1554
# ===> Epoch(315/2500): G_Loss: 8.9870
# ===> Epoch(316/2500): G_Loss: 8.6122
# ===> Epoch(317/2500): G_Loss: 8.1881
# ===> Epoch(318/2500): G_Loss: 9.0132
# ===> Epoch(319/2500): G_Loss: 8.8650
# ===> Epoch(320/2500): G_Loss: 8.0664
# ===> Epoch(321/2500): G_Loss: 10.1299
# ===> Epoch(322/2500): G_Loss: 8.7988
# ===> Epoch(323/2500): G_Loss: 8.0681
# ===> Epoch(324/2500): G_Loss: 9.1826
# ===> Epoch(325/2500): G_Loss: 8.5543
# ===> Epoch(326/2500): G_Loss: 8.2025
# ===> Epoch(327/2500): G_Loss: 9.3229
# ===> Epoch(328/2500): G_Loss: 8.0785
# ===> Epoch(329/2500): G_Loss: 8.5388
# ===> Epoch(330/2500): G_Loss: 8.1634
# ===> Epoch(331/2500): G_Loss: 8.2579
# ===> Epoch(332/2500): G_Loss: 8.0444
# ===> Epoch(333/2500): G_Loss: 8.0938
# ===> Epoch(334/2500): G_Loss: 8.1626
# ===> Epoch(335/2500): G_Loss: 7.5934
# ===> Epoch(336/2500): G_Loss: 7.9589
# ===> Epoch(337/2500): G_Loss: 7.6734
# ===> Epoch(338/2500): G_Loss: 8.3324
# ===> Epoch(339/2500): G_Loss: 8.2016
# ===> Epoch(340/2500): G_Loss: 7.7968
# ===> Epoch(341/2500): G_Loss: 7.6727
# ===> Epoch(342/2500): G_Loss: 6.8034
# ===> Epoch(343/2500): G_Loss: 8.3347
# ===> Epoch(344/2500): G_Loss: 7.5876
# ===> Epoch(345/2500): G_Loss: 6.9237
# ===> Epoch(346/2500): G_Loss: 8.3229
# ===> Epoch(347/2500): G_Loss: 7.5139
# ===> Epoch(348/2500): G_Loss: 6.6220
# ===> Epoch(349/2500): G_Loss: 7.4805
# ===> Epoch(350/2500): G_Loss: 6.4695
# ===> Epoch(351/2500): G_Loss: 6.7693
# ===> Epoch(352/2500): G_Loss: 8.3047
# ===> Epoch(353/2500): G_Loss: 6.7908
# ===> Epoch(354/2500): G_Loss: 8.5111
# ===> Epoch(355/2500): G_Loss: 7.4516
# ===> Epoch(356/2500): G_Loss: 7.9758
# ===> Epoch(357/2500): G_Loss: 6.4136
# ===> Epoch(358/2500): G_Loss: 7.7912
# ===> Epoch(359/2500): G_Loss: 7.2209
# ===> Epoch(360/2500): G_Loss: 6.4569
# ===> Epoch(361/2500): G_Loss: 6.4939
# ===> Epoch(362/2500): G_Loss: 7.3229
# ===> Epoch(363/2500): G_Loss: 6.2748
# ===> Epoch(364/2500): G_Loss: 7.1986
# ===> Epoch(365/2500): G_Loss: 8.1191
# ===> Epoch(366/2500): G_Loss: 7.3031
# ===> Epoch(367/2500): G_Loss: 6.4698
# ===> Epoch(368/2500): G_Loss: 6.3109
# ===> Epoch(369/2500): G_Loss: 8.5776
# ===> Epoch(370/2500): G_Loss: 6.9313
# ===> Epoch(371/2500): G_Loss: 8.1381
# ===> Epoch(372/2500): G_Loss: 6.2231
# ===> Epoch(373/2500): G_Loss: 6.2320
# ===> Epoch(374/2500): G_Loss: 7.4668
# ===> Epoch(375/2500): G_Loss: 7.7003
# ===> Epoch(376/2500): G_Loss: 6.2478
# ===> Epoch(377/2500): G_Loss: 6.4201
# ===> Epoch(378/2500): G_Loss: 6.5093
# ===> Epoch(379/2500): G_Loss: 6.2669
# ===> Epoch(380/2500): G_Loss: 5.8445
# ===> Epoch(381/2500): G_Loss: 6.2124
# ===> Epoch(382/2500): G_Loss: 5.9303
# ===> Epoch(383/2500): G_Loss: 5.9999
# ===> Epoch(384/2500): G_Loss: 6.1672
# ===> Epoch(385/2500): G_Loss: 7.0389
# ===> Epoch(386/2500): G_Loss: 7.2140
# ===> Epoch(387/2500): G_Loss: 7.0547
# ===> Epoch(388/2500): G_Loss: 9.2743
# ===> Epoch(389/2500): G_Loss: 7.8353
# ===> Epoch(390/2500): G_Loss: 7.5212
# ===> Epoch(391/2500): G_Loss: 9.5716
# ===> Epoch(392/2500): G_Loss: 13.0725
# ===> Epoch(393/2500): G_Loss: 6.6562
# ===> Epoch(394/2500): G_Loss: 6.3853
# ===> Epoch(395/2500): G_Loss: 6.9522
# ===> Epoch(396/2500): G_Loss: 6.3017
# ===> Epoch(397/2500): G_Loss: 6.0450
# ===> Epoch(398/2500): G_Loss: 6.1704
# ===> Epoch(399/2500): G_Loss: 6.3461
# ===> Epoch(400/2500): G_Loss: 6.1051
# ===> Epoch(401/2500): G_Loss: 6.4481
# ===> Epoch(402/2500): G_Loss: 6.1165
# ===> Epoch(403/2500): G_Loss: 6.1010
# ===> Epoch(404/2500): G_Loss: 6.0402
# ===> Epoch(405/2500): G_Loss: 7.0973
# ===> Epoch(406/2500): G_Loss: 7.5265
# ===> Epoch(407/2500): G_Loss: 6.2706
# ===> Epoch(408/2500): G_Loss: 6.4740
# ===> Epoch(409/2500): G_Loss: 5.3603
# ===> Epoch(410/2500): G_Loss: 6.0074
# ===> Epoch(411/2500): G_Loss: 5.3441
# ===> Epoch(412/2500): G_Loss: 5.2995
# ===> Epoch(413/2500): G_Loss: 5.2959
# ===> Epoch(414/2500): G_Loss: 5.6907
# ===> Epoch(415/2500): G_Loss: 6.3613
# ===> Epoch(416/2500): G_Loss: 5.2756
# ===> Epoch(417/2500): G_Loss: 5.9369
# ===> Epoch(418/2500): G_Loss: 5.8362
# ===> Epoch(419/2500): G_Loss: 5.4733
# ===> Epoch(420/2500): G_Loss: 5.0869
# ===> Epoch(421/2500): G_Loss: 5.2051
# ===> Epoch(422/2500): G_Loss: 5.1869
# ===> Epoch(423/2500): G_Loss: 5.3130
# ===> Epoch(424/2500): G_Loss: 5.3416
# ===> Epoch(425/2500): G_Loss: 6.0080
# ===> Epoch(426/2500): G_Loss: 4.9686
# ===> Epoch(427/2500): G_Loss: 6.1649
# ===> Epoch(428/2500): G_Loss: 5.7254
# ===> Epoch(429/2500): G_Loss: 4.8173
# ===> Epoch(430/2500): G_Loss: 5.3369
# ===> Epoch(431/2500): G_Loss: 4.7240
# ===> Epoch(432/2500): G_Loss: 5.0600
# ===> Epoch(433/2500): G_Loss: 6.0665
# ===> Epoch(434/2500): G_Loss: 5.3041
# ===> Epoch(435/2500): G_Loss: 6.0135
# ===> Epoch(436/2500): G_Loss: 4.8846
# ===> Epoch(437/2500): G_Loss: 4.8046
# ===> Epoch(438/2500): G_Loss: 5.1863
# ===> Epoch(439/2500): G_Loss: 5.0103
# ===> Epoch(440/2500): G_Loss: 5.7232
# ===> Epoch(441/2500): G_Loss: 4.3396
# ===> Epoch(442/2500): G_Loss: 4.8214
# ===> Epoch(443/2500): G_Loss: 5.1602
# ===> Epoch(444/2500): G_Loss: 5.0743
# ===> Epoch(445/2500): G_Loss: 5.1218
# ===> Epoch(446/2500): G_Loss: 6.8309
# ===> Epoch(447/2500): G_Loss: 5.6889
# ===> Epoch(448/2500): G_Loss: 4.7950
# ===> Epoch(449/2500): G_Loss: 7.3320
# ===> Epoch(450/2500): G_Loss: 5.3892
# ===> Epoch(451/2500): G_Loss: 5.3191
# ===> Epoch(452/2500): G_Loss: 5.0350
# ===> Epoch(453/2500): G_Loss: 5.1846
# ===> Epoch(454/2500): G_Loss: 4.8371
# ===> Epoch(455/2500): G_Loss: 4.9262
# ===> Epoch(456/2500): G_Loss: 5.7724
# ===> Epoch(457/2500): G_Loss: 4.7580
# ===> Epoch(458/2500): G_Loss: 4.8929
# ===> Epoch(459/2500): G_Loss: 5.8163
# ===> Epoch(460/2500): G_Loss: 6.3251
# ===> Epoch(461/2500): G_Loss: 4.7613
# ===> Epoch(462/2500): G_Loss: 4.5709
# ===> Epoch(463/2500): G_Loss: 5.1030
# ===> Epoch(464/2500): G_Loss: 6.1263
# ===> Epoch(465/2500): G_Loss: 6.0633
# ===> Epoch(466/2500): G_Loss: 5.5283
# ===> Epoch(467/2500): G_Loss: 4.7414
# ===> Epoch(468/2500): G_Loss: 4.5879
# ===> Epoch(469/2500): G_Loss: 5.8441
# ===> Epoch(470/2500): G_Loss: 4.9651
# ===> Epoch(471/2500): G_Loss: 5.2952
# ===> Epoch(472/2500): G_Loss: 5.8386
# ===> Epoch(473/2500): G_Loss: 4.7559
# ===> Epoch(474/2500): G_Loss: 4.5048
# ===> Epoch(475/2500): G_Loss: 4.8525
# ===> Epoch(476/2500): G_Loss: 5.4417
# ===> Epoch(477/2500): G_Loss: 4.6570
# ===> Epoch(478/2500): G_Loss: 5.1818
# ===> Epoch(479/2500): G_Loss: 6.0113
# ===> Epoch(480/2500): G_Loss: 4.4751
# ===> Epoch(481/2500): G_Loss: 4.8744
# ===> Epoch(482/2500): G_Loss: 5.8494
# ===> Epoch(483/2500): G_Loss: 5.0099
# ===> Epoch(484/2500): G_Loss: 4.6386
# ===> Epoch(485/2500): G_Loss: 5.0831
# ===> Epoch(486/2500): G_Loss: 5.6007
# ===> Epoch(487/2500): G_Loss: 4.0602
# ===> Epoch(488/2500): G_Loss: 5.0922
# ===> Epoch(489/2500): G_Loss: 5.2919
# ===> Epoch(490/2500): G_Loss: 4.9868
# ===> Epoch(491/2500): G_Loss: 5.3574
# ===> Epoch(492/2500): G_Loss: 4.8397
# ===> Epoch(493/2500): G_Loss: 6.0434
# ===> Epoch(494/2500): G_Loss: 5.0877
# ===> Epoch(495/2500): G_Loss: 4.7022
# ===> Epoch(496/2500): G_Loss: 4.7948
# ===> Epoch(497/2500): G_Loss: 4.5286
# ===> Epoch(498/2500): G_Loss: 4.5466
# ===> Epoch(499/2500): G_Loss: 5.6784
# ===> Epoch(500/2500): G_Loss: 5.0508
# ===> Epoch(501/2500): G_Loss: 4.4383
# ===> Epoch(502/2500): G_Loss: 4.4639
# ===> Epoch(503/2500): G_Loss: 4.8220
# ===> Epoch(504/2500): G_Loss: 5.2573
# ===> Epoch(505/2500): G_Loss: 4.2821
# ===> Epoch(506/2500): G_Loss: 5.0597
# ===> Epoch(507/2500): G_Loss: 5.1469
# ===> Epoch(508/2500): G_Loss: 4.3745
# ===> Epoch(509/2500): G_Loss: 5.8434
# ===> Epoch(510/2500): G_Loss: 5.9246
# ===> Epoch(511/2500): G_Loss: 5.7106
# ===> Epoch(512/2500): G_Loss: 7.9352
# ===> Epoch(513/2500): G_Loss: 5.0477
# ===> Epoch(514/2500): G_Loss: 4.9635
# ===> Epoch(515/2500): G_Loss: 6.2994
# ===> Epoch(516/2500): G_Loss: 5.0047
# ===> Epoch(517/2500): G_Loss: 6.1759
# ===> Epoch(518/2500): G_Loss: 4.7486
# ===> Epoch(519/2500): G_Loss: 6.9567
# ===> Epoch(520/2500): G_Loss: 4.7259
# ===> Epoch(521/2500): G_Loss: 5.0556
# ===> Epoch(522/2500): G_Loss: 7.2158
# ===> Epoch(523/2500): G_Loss: 5.4795
# ===> Epoch(524/2500): G_Loss: 5.3730
# ===> Epoch(525/2500): G_Loss: 5.0347
# ===> Epoch(526/2500): G_Loss: 5.2364
# ===> Epoch(527/2500): G_Loss: 5.1875
# ===> Epoch(528/2500): G_Loss: 5.6402
# ===> Epoch(529/2500): G_Loss: 4.8721
# ===> Epoch(530/2500): G_Loss: 4.7723
# ===> Epoch(531/2500): G_Loss: 4.9848
# ===> Epoch(532/2500): G_Loss: 4.7627
# ===> Epoch(533/2500): G_Loss: 5.5438
# ===> Epoch(534/2500): G_Loss: 5.3300
# ===> Epoch(535/2500): G_Loss: 5.0048
# ===> Epoch(536/2500): G_Loss: 4.7169
# ===> Epoch(537/2500): G_Loss: 4.6876
# ===> Epoch(538/2500): G_Loss: 4.6888
# ===> Epoch(539/2500): G_Loss: 4.6625
# ===> Epoch(540/2500): G_Loss: 4.8769
# ===> Epoch(541/2500): G_Loss: 4.2317
# ===> Epoch(542/2500): G_Loss: 4.7845
# ===> Epoch(543/2500): G_Loss: 5.1456
# ===> Epoch(544/2500): G_Loss: 4.2282
# ===> Epoch(545/2500): G_Loss: 4.1719
# ===> Epoch(546/2500): G_Loss: 3.6991
# ===> Epoch(547/2500): G_Loss: 4.4697
# ===> Epoch(548/2500): G_Loss: 4.3966
# ===> Epoch(549/2500): G_Loss: 4.0973
# ===> Epoch(550/2500): G_Loss: 6.0982
# ===> Epoch(551/2500): G_Loss: 4.2579
# ===> Epoch(552/2500): G_Loss: 4.1208
# ===> Epoch(553/2500): G_Loss: 4.8322
# ===> Epoch(554/2500): G_Loss: 4.8445
# ===> Epoch(555/2500): G_Loss: 3.7254
# ===> Epoch(556/2500): G_Loss: 5.4799
# ===> Epoch(557/2500): G_Loss: 4.1414
# ===> Epoch(558/2500): G_Loss: 3.5218
# ===> Epoch(559/2500): G_Loss: 3.8132
# ===> Epoch(560/2500): G_Loss: 3.7176
# ===> Epoch(561/2500): G_Loss: 4.8750
# ===> Epoch(562/2500): G_Loss: 4.3534
# ===> Epoch(563/2500): G_Loss: 3.9805
# ===> Epoch(564/2500): G_Loss: 3.8246
# ===> Epoch(565/2500): G_Loss: 4.0343
# ===> Epoch(566/2500): G_Loss: 4.0213
# ===> Epoch(567/2500): G_Loss: 3.9333
# ===> Epoch(568/2500): G_Loss: 4.0693
# ===> Epoch(569/2500): G_Loss: 7.0558
# ===> Epoch(570/2500): G_Loss: 4.1772
# ===> Epoch(571/2500): G_Loss: 4.2749
# ===> Epoch(572/2500): G_Loss: 6.6419
# ===> Epoch(573/2500): G_Loss: 3.7216
# ===> Epoch(574/2500): G_Loss: 4.2111
# ===> Epoch(575/2500): G_Loss: 3.3938
# ===> Epoch(576/2500): G_Loss: 5.0517
# ===> Epoch(577/2500): G_Loss: 3.8995
# ===> Epoch(578/2500): G_Loss: 4.7876
# ===> Epoch(579/2500): G_Loss: 4.0514
# ===> Epoch(580/2500): G_Loss: 3.6247
# ===> Epoch(581/2500): G_Loss: 3.8681
# ===> Epoch(582/2500): G_Loss: 3.7829
# ===> Epoch(583/2500): G_Loss: 3.5837
# ===> Epoch(584/2500): G_Loss: 3.7739
# ===> Epoch(585/2500): G_Loss: 3.5113
# ===> Epoch(586/2500): G_Loss: 3.4900
# ===> Epoch(587/2500): G_Loss: 3.9551
# ===> Epoch(588/2500): G_Loss: 3.9039
# ===> Epoch(589/2500): G_Loss: 3.7477
# ===> Epoch(590/2500): G_Loss: 3.6263
# ===> Epoch(591/2500): G_Loss: 3.0835
# ===> Epoch(592/2500): G_Loss: 3.1051
# ===> Epoch(593/2500): G_Loss: 3.5958
# ===> Epoch(594/2500): G_Loss: 3.1542
# ===> Epoch(595/2500): G_Loss: 3.1828
# ===> Epoch(596/2500): G_Loss: 3.4936
# ===> Epoch(597/2500): G_Loss: 3.6620
# ===> Epoch(598/2500): G_Loss: 4.1729
# ===> Epoch(599/2500): G_Loss: 3.4393
# ===> Epoch(600/2500): G_Loss: 3.2756
# ===> Epoch(601/2500): G_Loss: 4.2040
# ===> Epoch(602/2500): G_Loss: 3.4566
# ===> Epoch(603/2500): G_Loss: 3.1840
# ===> Epoch(604/2500): G_Loss: 3.5974
# ===> Epoch(605/2500): G_Loss: 3.2222
# ===> Epoch(606/2500): G_Loss: 3.8148
# ===> Epoch(607/2500): G_Loss: 3.2036
# ===> Epoch(608/2500): G_Loss: 3.7980
# ===> Epoch(609/2500): G_Loss: 3.6472
# ===> Epoch(610/2500): G_Loss: 3.3271
# ===> Epoch(611/2500): G_Loss: 2.8435
# ===> Epoch(612/2500): G_Loss: 3.5238
# ===> Epoch(613/2500): G_Loss: 3.5104
# ===> Epoch(614/2500): G_Loss: 3.1577
# ===> Epoch(615/2500): G_Loss: 3.9153
# ===> Epoch(616/2500): G_Loss: 3.2844
# ===> Epoch(617/2500): G_Loss: 2.8777
# ===> Epoch(618/2500): G_Loss: 3.3634
# ===> Epoch(619/2500): G_Loss: 3.4998
# ===> Epoch(620/2500): G_Loss: 3.3816
# ===> Epoch(621/2500): G_Loss: 2.9855
# ===> Epoch(622/2500): G_Loss: 3.3204
# ===> Epoch(623/2500): G_Loss: 3.0953
# ===> Epoch(624/2500): G_Loss: 2.9455
# ===> Epoch(625/2500): G_Loss: 3.1463
# ===> Epoch(626/2500): G_Loss: 3.3561
# ===> Epoch(627/2500): G_Loss: 3.1263
# ===> Epoch(628/2500): G_Loss: 2.9797
# ===> Epoch(629/2500): G_Loss: 2.9048
# ===> Epoch(630/2500): G_Loss: 3.0090
# ===> Epoch(631/2500): G_Loss: 2.9311
# ===> Epoch(632/2500): G_Loss: 3.4881
# ===> Epoch(633/2500): G_Loss: 2.9421
# ===> Epoch(634/2500): G_Loss: 3.5971
# ===> Epoch(635/2500): G_Loss: 3.3046
# ===> Epoch(636/2500): G_Loss: 3.3297
# ===> Epoch(637/2500): G_Loss: 3.8334
# ===> Epoch(638/2500): G_Loss: 2.7959
# ===> Epoch(639/2500): G_Loss: 3.1562
# ===> Epoch(640/2500): G_Loss: 3.2833
# ===> Epoch(641/2500): G_Loss: 5.6920
# ===> Epoch(642/2500): G_Loss: 3.3202
# ===> Epoch(643/2500): G_Loss: 3.9603
# ===> Epoch(644/2500): G_Loss: 3.0056
# ===> Epoch(645/2500): G_Loss: 4.5021
# ===> Epoch(646/2500): G_Loss: 2.9636
# ===> Epoch(647/2500): G_Loss: 2.8888
# ===> Epoch(648/2500): G_Loss: 4.4888
# ===> Epoch(649/2500): G_Loss: 3.6780
# ===> Epoch(650/2500): G_Loss: 3.4042
# ===> Epoch(651/2500): G_Loss: 3.3161
# ===> Epoch(652/2500): G_Loss: 3.3311
# ===> Epoch(653/2500): G_Loss: 2.9302
# ===> Epoch(654/2500): G_Loss: 3.2236
# ===> Epoch(655/2500): G_Loss: 2.9508
# ===> Epoch(656/2500): G_Loss: 3.8219
# ===> Epoch(657/2500): G_Loss: 4.1535
# ===> Epoch(658/2500): G_Loss: 5.0607
# ===> Epoch(659/2500): G_Loss: 3.2591
# ===> Epoch(660/2500): G_Loss: 4.6061
# ===> Epoch(661/2500): G_Loss: 3.3518
# ===> Epoch(662/2500): G_Loss: 3.9932
# ===> Epoch(663/2500): G_Loss: 3.3782
# ===> Epoch(664/2500): G_Loss: 2.9536
# ===> Epoch(665/2500): G_Loss: 3.6094
# ===> Epoch(666/2500): G_Loss: 3.0231
# ===> Epoch(667/2500): G_Loss: 3.1554
# ===> Epoch(668/2500): G_Loss: 3.9209
# ===> Epoch(669/2500): G_Loss: 3.1036
# ===> Epoch(670/2500): G_Loss: 3.0507
# ===> Epoch(671/2500): G_Loss: 3.8228
# ===> Epoch(672/2500): G_Loss: 2.6825
# ===> Epoch(673/2500): G_Loss: 3.0198
# ===> Epoch(674/2500): G_Loss: 3.0509
# ===> Epoch(675/2500): G_Loss: 3.3360
# ===> Epoch(676/2500): G_Loss: 3.6473
# ===> Epoch(677/2500): G_Loss: 3.0907
# ===> Epoch(678/2500): G_Loss: 3.2204
# ===> Epoch(679/2500): G_Loss: 4.7256
# ===> Epoch(680/2500): G_Loss: 3.1638
# ===> Epoch(681/2500): G_Loss: 3.2403
# ===> Epoch(682/2500): G_Loss: 3.4961
# ===> Epoch(683/2500): G_Loss: 3.8752
# ===> Epoch(684/2500): G_Loss: 2.9996
# ===> Epoch(685/2500): G_Loss: 3.6637
# ===> Epoch(686/2500): G_Loss: 3.5739
# ===> Epoch(687/2500): G_Loss: 2.9349
# ===> Epoch(688/2500): G_Loss: 3.8116
# ===> Epoch(689/2500): G_Loss: 2.8541
# ===> Epoch(690/2500): G_Loss: 4.6239
# ===> Epoch(691/2500): G_Loss: 3.6126
# ===> Epoch(692/2500): G_Loss: 2.9296
# ===> Epoch(693/2500): G_Loss: 6.3390
# ===> Epoch(694/2500): G_Loss: 2.7109
# ===> Epoch(695/2500): G_Loss: 3.7789
# ===> Epoch(696/2500): G_Loss: 4.0897
# ===> Epoch(697/2500): G_Loss: 2.6917
# ===> Epoch(698/2500): G_Loss: 2.9434
# ===> Epoch(699/2500): G_Loss: 2.9034
# ===> Epoch(700/2500): G_Loss: 3.4538
# ===> Epoch(701/2500): G_Loss: 2.8644
# ===> Epoch(702/2500): G_Loss: 3.5946
# ===> Epoch(703/2500): G_Loss: 2.7927
# ===> Epoch(704/2500): G_Loss: 3.7253
# ===> Epoch(705/2500): G_Loss: 3.5992
# ===> Epoch(706/2500): G_Loss: 2.8008
# ===> Epoch(707/2500): G_Loss: 3.0733
# ===> Epoch(708/2500): G_Loss: 3.1392
# ===> Epoch(709/2500): G_Loss: 3.2129
# ===> Epoch(710/2500): G_Loss: 2.8489
# ===> Epoch(711/2500): G_Loss: 2.8350
# ===> Epoch(712/2500): G_Loss: 3.2501
# ===> Epoch(713/2500): G_Loss: 3.5368
# ===> Epoch(714/2500): G_Loss: 3.2044
# ===> Epoch(715/2500): G_Loss: 2.9193
# ===> Epoch(716/2500): G_Loss: 2.9379
# ===> Epoch(717/2500): G_Loss: 3.8049
# ===> Epoch(718/2500): G_Loss: 3.1498
# ===> Epoch(719/2500): G_Loss: 2.9189
# ===> Epoch(720/2500): G_Loss: 4.3526
# ===> Epoch(721/2500): G_Loss: 3.0342
# ===> Epoch(722/2500): G_Loss: 2.9660
# ===> Epoch(723/2500): G_Loss: 3.2083
# ===> Epoch(724/2500): G_Loss: 3.4346
# ===> Epoch(725/2500): G_Loss: 2.9395
# ===> Epoch(726/2500): G_Loss: 3.2480
# ===> Epoch(727/2500): G_Loss: 3.7767
# ===> Epoch(728/2500): G_Loss: 3.4113
# ===> Epoch(729/2500): G_Loss: 3.2640
# ===> Epoch(730/2500): G_Loss: 3.3722
# ===> Epoch(731/2500): G_Loss: 2.5662
# ===> Epoch(732/2500): G_Loss: 2.8337
# ===> Epoch(733/2500): G_Loss: 2.6313
# ===> Epoch(734/2500): G_Loss: 2.8641
# ===> Epoch(735/2500): G_Loss: 3.2881
# ===> Epoch(736/2500): G_Loss: 2.9155
# ===> Epoch(737/2500): G_Loss: 2.9152
# ===> Epoch(738/2500): G_Loss: 2.9753
# ===> Epoch(739/2500): G_Loss: 2.7498
# ===> Epoch(740/2500): G_Loss: 3.1775
# ===> Epoch(741/2500): G_Loss: 3.4700
# ===> Epoch(742/2500): G_Loss: 3.2122
# ===> Epoch(743/2500): G_Loss: 2.9224
# ===> Epoch(744/2500): G_Loss: 2.7999
# ===> Epoch(745/2500): G_Loss: 3.0644
# ===> Epoch(746/2500): G_Loss: 3.0911
# ===> Epoch(747/2500): G_Loss: 2.9013
# ===> Epoch(748/2500): G_Loss: 2.3917
# ===> Epoch(749/2500): G_Loss: 5.0915
# ===> Epoch(750/2500): G_Loss: 3.7297
# ===> Epoch(751/2500): G_Loss: 2.5246
# ===> Epoch(752/2500): G_Loss: 2.5073
# ===> Epoch(753/2500): G_Loss: 3.5519
# ===> Epoch(754/2500): G_Loss: 2.9578
# ===> Epoch(755/2500): G_Loss: 3.2767
# ===> Epoch(756/2500): G_Loss: 3.1006
# ===> Epoch(757/2500): G_Loss: 3.2664
# ===> Epoch(758/2500): G_Loss: 3.2870
# ===> Epoch(759/2500): G_Loss: 2.6346
# ===> Epoch(760/2500): G_Loss: 4.0658
# ===> Epoch(761/2500): G_Loss: 3.3587
# ===> Epoch(762/2500): G_Loss: 2.8365
# ===> Epoch(763/2500): G_Loss: 3.0655
# ===> Epoch(764/2500): G_Loss: 2.6345
# ===> Epoch(765/2500): G_Loss: 2.8403
# ===> Epoch(766/2500): G_Loss: 3.3352
# ===> Epoch(767/2500): G_Loss: 3.1564
# ===> Epoch(768/2500): G_Loss: 4.0095
# ===> Epoch(769/2500): G_Loss: 3.1388
# ===> Epoch(770/2500): G_Loss: 3.7434
# ===> Epoch(771/2500): G_Loss: 4.3786
# ===> Epoch(772/2500): G_Loss: 4.0302
# ===> Epoch(773/2500): G_Loss: 3.5001
# ===> Epoch(774/2500): G_Loss: 4.3211
# ===> Epoch(775/2500): G_Loss: 3.0898
# ===> Epoch(776/2500): G_Loss: 3.8364
# ===> Epoch(777/2500): G_Loss: 4.6058
# ===> Epoch(778/2500): G_Loss: 5.0472
# ===> Epoch(779/2500): G_Loss: 3.5603
# ===> Epoch(780/2500): G_Loss: 7.1333
# ===> Epoch(781/2500): G_Loss: 4.5518
# ===> Epoch(782/2500): G_Loss: 3.9554
# ===> Epoch(783/2500): G_Loss: 4.2268
# ===> Epoch(784/2500): G_Loss: 4.2662
# ===> Epoch(785/2500): G_Loss: 2.9205
# ===> Epoch(786/2500): G_Loss: 3.1805
# ===> Epoch(787/2500): G_Loss: 4.0065
# ===> Epoch(788/2500): G_Loss: 3.3569
# ===> Epoch(789/2500): G_Loss: 2.7537
# ===> Epoch(790/2500): G_Loss: 3.0632
# ===> Epoch(791/2500): G_Loss: 3.8953
# ===> Epoch(792/2500): G_Loss: 4.8633
# ===> Epoch(793/2500): G_Loss: 2.8097
# ===> Epoch(794/2500): G_Loss: 3.9551
# ===> Epoch(795/2500): G_Loss: 4.5235
# ===> Epoch(796/2500): G_Loss: 2.7131
# ===> Epoch(797/2500): G_Loss: 2.9692
# ===> Epoch(798/2500): G_Loss: 2.9389
# ===> Epoch(799/2500): G_Loss: 2.8800
# ===> Epoch(800/2500): G_Loss: 2.6224
# ===> Epoch(801/2500): G_Loss: 3.2512
# ===> Epoch(802/2500): G_Loss: 2.5727
# ===> Epoch(803/2500): G_Loss: 3.1047
# ===> Epoch(804/2500): G_Loss: 2.6758
# ===> Epoch(805/2500): G_Loss: 3.0155
# ===> Epoch(806/2500): G_Loss: 2.7277
# ===> Epoch(807/2500): G_Loss: 3.2926
# ===> Epoch(808/2500): G_Loss: 2.4670
# ===> Epoch(809/2500): G_Loss: 3.0055
# ===> Epoch(810/2500): G_Loss: 2.7630
# ===> Epoch(811/2500): G_Loss: 2.2595
# ===> Epoch(812/2500): G_Loss: 2.6474
# ===> Epoch(813/2500): G_Loss: 3.0827
# ===> Epoch(814/2500): G_Loss: 4.2000
# ===> Epoch(815/2500): G_Loss: 3.0703
# ===> Epoch(816/2500): G_Loss: 4.5037
# ===> Epoch(817/2500): G_Loss: 2.4832
# ===> Epoch(818/2500): G_Loss: 2.3008
# ===> Epoch(819/2500): G_Loss: 2.6533
# ===> Epoch(820/2500): G_Loss: 2.7638
# ===> Epoch(821/2500): G_Loss: 2.9304
# ===> Epoch(822/2500): G_Loss: 2.2605
# ===> Epoch(823/2500): G_Loss: 2.4621
# ===> Epoch(824/2500): G_Loss: 2.8199
# ===> Epoch(825/2500): G_Loss: 2.7928
# ===> Epoch(826/2500): G_Loss: 2.6198
# ===> Epoch(827/2500): G_Loss: 2.9551
# ===> Epoch(828/2500): G_Loss: 2.9477
# ===> Epoch(829/2500): G_Loss: 2.3981
# ===> Epoch(830/2500): G_Loss: 2.7019
# ===> Epoch(831/2500): G_Loss: 2.2822
# ===> Epoch(832/2500): G_Loss: 3.4827
# ===> Epoch(833/2500): G_Loss: 2.5269
# ===> Epoch(834/2500): G_Loss: 2.5597
# ===> Epoch(835/2500): G_Loss: 3.1261
# ===> Epoch(836/2500): G_Loss: 2.0173
# ===> Epoch(837/2500): G_Loss: 2.2208
# ===> Epoch(838/2500): G_Loss: 3.2942
# ===> Epoch(839/2500): G_Loss: 2.5371
# ===> Epoch(840/2500): G_Loss: 2.3760
# ===> Epoch(841/2500): G_Loss: 2.5856
# ===> Epoch(842/2500): G_Loss: 2.0815
# ===> Epoch(843/2500): G_Loss: 3.4819
# ===> Epoch(844/2500): G_Loss: 3.3979
# ===> Epoch(845/2500): G_Loss: 3.0136
# ===> Epoch(846/2500): G_Loss: 2.8275
# ===> Epoch(847/2500): G_Loss: 3.5915
# ===> Epoch(848/2500): G_Loss: 2.1020
# ===> Epoch(849/2500): G_Loss: 2.4311
# ===> Epoch(850/2500): G_Loss: 3.3030
# ===> Epoch(851/2500): G_Loss: 2.7887
# ===> Epoch(852/2500): G_Loss: 2.7173
# ===> Epoch(853/2500): G_Loss: 2.1298
# ===> Epoch(854/2500): G_Loss: 2.2400
# ===> Epoch(855/2500): G_Loss: 2.9534
# ===> Epoch(856/2500): G_Loss: 2.3611
# ===> Epoch(857/2500): G_Loss: 2.8633
# ===> Epoch(858/2500): G_Loss: 3.5387
# ===> Epoch(859/2500): G_Loss: 3.4298
# ===> Epoch(860/2500): G_Loss: 2.6766
# ===> Epoch(861/2500): G_Loss: 3.1387
# ===> Epoch(862/2500): G_Loss: 3.4857
# ===> Epoch(863/2500): G_Loss: 2.5426
# ===> Epoch(864/2500): G_Loss: 2.7032
# ===> Epoch(865/2500): G_Loss: 2.2905
# ===> Epoch(866/2500): G_Loss: 2.7225
# ===> Epoch(867/2500): G_Loss: 2.4700
# ===> Epoch(868/2500): G_Loss: 2.0316
# ===> Epoch(869/2500): G_Loss: 2.5083
# ===> Epoch(870/2500): G_Loss: 2.4930
# ===> Epoch(871/2500): G_Loss: 2.2719
# ===> Epoch(872/2500): G_Loss: 2.8650
# ===> Epoch(873/2500): G_Loss: 2.7078
# ===> Epoch(874/2500): G_Loss: 3.9927
# ===> Epoch(875/2500): G_Loss: 2.3043
# ===> Epoch(876/2500): G_Loss: 2.1304
# ===> Epoch(877/2500): G_Loss: 2.6979
# ===> Epoch(878/2500): G_Loss: 5.0263
# ===> Epoch(879/2500): G_Loss: 2.7662
# ===> Epoch(880/2500): G_Loss: 4.1981
# ===> Epoch(881/2500): G_Loss: 5.0384
# ===> Epoch(882/2500): G_Loss: 2.3502
# ===> Epoch(883/2500): G_Loss: 2.0700
# ===> Epoch(884/2500): G_Loss: 5.2385
# ===> Epoch(885/2500): G_Loss: 3.5942
# ===> Epoch(886/2500): G_Loss: 2.7032
# ===> Epoch(887/2500): G_Loss: 2.5794
# ===> Epoch(888/2500): G_Loss: 5.3474
# ===> Epoch(889/2500): G_Loss: 4.4288
# ===> Epoch(890/2500): G_Loss: 2.8376
# ===> Epoch(891/2500): G_Loss: 4.9068
# ===> Epoch(892/2500): G_Loss: 5.0756
# ===> Epoch(893/2500): G_Loss: 3.0445
# ===> Epoch(894/2500): G_Loss: 4.7727
# ===> Epoch(895/2500): G_Loss: 3.1736
# ===> Epoch(896/2500): G_Loss: 3.0755
# ===> Epoch(897/2500): G_Loss: 2.6018
# ===> Epoch(898/2500): G_Loss: 2.8457
# ===> Epoch(899/2500): G_Loss: 2.7021
# ===> Epoch(900/2500): G_Loss: 2.8130
# ===> Epoch(901/2500): G_Loss: 2.2603
# ===> Epoch(902/2500): G_Loss: 2.9095
# ===> Epoch(903/2500): G_Loss: 2.2400
# ===> Epoch(904/2500): G_Loss: 2.3676
# ===> Epoch(905/2500): G_Loss: 3.3764
# ===> Epoch(906/2500): G_Loss: 2.6909
# ===> Epoch(907/2500): G_Loss: 2.5072
# ===> Epoch(908/2500): G_Loss: 2.7985
# ===> Epoch(909/2500): G_Loss: 2.4158
# ===> Epoch(910/2500): G_Loss: 3.1234
# ===> Epoch(911/2500): G_Loss: 3.2036
# ===> Epoch(912/2500): G_Loss: 2.1947
# ===> Epoch(913/2500): G_Loss: 2.9103
# ===> Epoch(914/2500): G_Loss: 3.5893
# ===> Epoch(915/2500): G_Loss: 2.7734
# ===> Epoch(916/2500): G_Loss: 4.0838
# ===> Epoch(917/2500): G_Loss: 2.2840
# ===> Epoch(918/2500): G_Loss: 3.0213
# ===> Epoch(919/2500): G_Loss: 2.8077
# ===> Epoch(920/2500): G_Loss: 3.0303
# ===> Epoch(921/2500): G_Loss: 3.0939
# ===> Epoch(922/2500): G_Loss: 3.0232
# ===> Epoch(923/2500): G_Loss: 3.3662
# ===> Epoch(924/2500): G_Loss: 3.4509
# ===> Epoch(925/2500): G_Loss: 2.5711
# ===> Epoch(926/2500): G_Loss: 3.3726
# ===> Epoch(927/2500): G_Loss: 2.9069
# ===> Epoch(928/2500): G_Loss: 3.2981
# ===> Epoch(929/2500): G_Loss: 3.5512
# ===> Epoch(930/2500): G_Loss: 3.4164
# ===> Epoch(931/2500): G_Loss: 2.6560
# ===> Epoch(932/2500): G_Loss: 3.1927
# ===> Epoch(933/2500): G_Loss: 2.8834
# ===> Epoch(934/2500): G_Loss: 2.5568
# ===> Epoch(935/2500): G_Loss: 3.4247
# ===> Epoch(936/2500): G_Loss: 2.7406
# ===> Epoch(937/2500): G_Loss: 3.3539
# ===> Epoch(938/2500): G_Loss: 3.8735
# ===> Epoch(939/2500): G_Loss: 2.9341
# ===> Epoch(940/2500): G_Loss: 2.2439
# ===> Epoch(941/2500): G_Loss: 2.6652
# ===> Epoch(942/2500): G_Loss: 3.2681
# ===> Epoch(943/2500): G_Loss: 3.1499
# ===> Epoch(944/2500): G_Loss: 2.4448
# ===> Epoch(945/2500): G_Loss: 2.5898
# ===> Epoch(946/2500): G_Loss: 2.9115
# ===> Epoch(947/2500): G_Loss: 2.6205
# ===> Epoch(948/2500): G_Loss: 2.3471
# ===> Epoch(949/2500): G_Loss: 3.3285
# ===> Epoch(950/2500): G_Loss: 2.6273
# ===> Epoch(951/2500): G_Loss: 2.7695
# ===> Epoch(952/2500): G_Loss: 2.1106
# ===> Epoch(953/2500): G_Loss: 2.8205
# ===> Epoch(954/2500): G_Loss: 3.2025
# ===> Epoch(955/2500): G_Loss: 3.1636
# ===> Epoch(956/2500): G_Loss: 2.1919
# ===> Epoch(957/2500): G_Loss: 2.6088
# ===> Epoch(958/2500): G_Loss: 2.4942
# ===> Epoch(959/2500): G_Loss: 2.2851
# ===> Epoch(960/2500): G_Loss: 2.7901
# ===> Epoch(961/2500): G_Loss: 2.8451
# ===> Epoch(962/2500): G_Loss: 2.4521
# ===> Epoch(963/2500): G_Loss: 2.0911
# ===> Epoch(964/2500): G_Loss: 1.9569
# ===> Epoch(965/2500): G_Loss: 2.4508
# ===> Epoch(966/2500): G_Loss: 2.4874
# ===> Epoch(967/2500): G_Loss: 2.8156
# ===> Epoch(968/2500): G_Loss: 2.2674
# ===> Epoch(969/2500): G_Loss: 4.4931
# ===> Epoch(970/2500): G_Loss: 2.5535
# ===> Epoch(971/2500): G_Loss: 2.1252
# ===> Epoch(972/2500): G_Loss: 2.5922
# ===> Epoch(973/2500): G_Loss: 2.8447
# ===> Epoch(974/2500): G_Loss: 2.2318
# ===> Epoch(975/2500): G_Loss: 2.8763
# ===> Epoch(976/2500): G_Loss: 2.8343
# ===> Epoch(977/2500): G_Loss: 2.2739
# ===> Epoch(978/2500): G_Loss: 2.1138
# ===> Epoch(979/2500): G_Loss: 2.0213
# ===> Epoch(980/2500): G_Loss: 2.3375
# ===> Epoch(981/2500): G_Loss: 2.1294
# ===> Epoch(982/2500): G_Loss: 2.1388
# ===> Epoch(983/2500): G_Loss: 2.0696
# ===> Epoch(984/2500): G_Loss: 2.5220
# ===> Epoch(985/2500): G_Loss: 2.5866
# ===> Epoch(986/2500): G_Loss: 1.9088
# ===> Epoch(987/2500): G_Loss: 1.8688
# ===> Epoch(988/2500): G_Loss: 2.0172
# ===> Epoch(989/2500): G_Loss: 1.9843
# ===> Epoch(990/2500): G_Loss: 2.3365
# ===> Epoch(991/2500): G_Loss: 2.3373
# ===> Epoch(992/2500): G_Loss: 1.8546
# ===> Epoch(993/2500): G_Loss: 2.1950
# ===> Epoch(994/2500): G_Loss: 2.6636
# ===> Epoch(995/2500): G_Loss: 3.0587
# ===> Epoch(996/2500): G_Loss: 1.9551
# ===> Epoch(997/2500): G_Loss: 2.2523
# ===> Epoch(998/2500): G_Loss: 3.2418
# ===> Epoch(999/2500): G_Loss: 2.2895
# ===> Epoch(1000/2500): G_Loss: 2.1409
# ===> Epoch(1001/2500): G_Loss: 1.9670
# ===> Epoch(1002/2500): G_Loss: 2.3316
# ===> Epoch(1003/2500): G_Loss: 2.2867
# ===> Epoch(1004/2500): G_Loss: 2.9656
# ===> Epoch(1005/2500): G_Loss: 3.2744
# ===> Epoch(1006/2500): G_Loss: 2.1165
# ===> Epoch(1007/2500): G_Loss: 2.6347
# ===> Epoch(1008/2500): G_Loss: 2.2304
# ===> Epoch(1009/2500): G_Loss: 2.3923
# ===> Epoch(1010/2500): G_Loss: 2.8729
# ===> Epoch(1011/2500): G_Loss: 2.4913
# ===> Epoch(1012/2500): G_Loss: 2.5649
# ===> Epoch(1013/2500): G_Loss: 2.7938
# ===> Epoch(1014/2500): G_Loss: 2.6637
# ===> Epoch(1015/2500): G_Loss: 2.7465
# ===> Epoch(1016/2500): G_Loss: 2.3020
# ===> Epoch(1017/2500): G_Loss: 2.5573
# ===> Epoch(1018/2500): G_Loss: 3.0483
# ===> Epoch(1019/2500): G_Loss: 3.3751
# ===> Epoch(1020/2500): G_Loss: 3.0305
# ===> Epoch(1021/2500): G_Loss: 2.0177
# ===> Epoch(1022/2500): G_Loss: 2.1748
# ===> Epoch(1023/2500): G_Loss: 2.6389
# ===> Epoch(1024/2500): G_Loss: 2.5555
# ===> Epoch(1025/2500): G_Loss: 2.4349
# ===> Epoch(1026/2500): G_Loss: 2.3498
# ===> Epoch(1027/2500): G_Loss: 2.5853
# ===> Epoch(1028/2500): G_Loss: 2.1239
# ===> Epoch(1029/2500): G_Loss: 2.3341
# ===> Epoch(1030/2500): G_Loss: 2.1991
# ===> Epoch(1031/2500): G_Loss: 2.3632
# ===> Epoch(1032/2500): G_Loss: 2.3691
# ===> Epoch(1033/2500): G_Loss: 2.4098
# ===> Epoch(1034/2500): G_Loss: 2.5257
# ===> Epoch(1035/2500): G_Loss: 2.7743
# ===> Epoch(1036/2500): G_Loss: 1.9684
# ===> Epoch(1037/2500): G_Loss: 1.9212
# ===> Epoch(1038/2500): G_Loss: 2.0116
# ===> Epoch(1039/2500): G_Loss: 1.8077
# ===> Epoch(1040/2500): G_Loss: 2.2506
# ===> Epoch(1041/2500): G_Loss: 1.9701
# ===> Epoch(1042/2500): G_Loss: 2.8190
# ===> Epoch(1043/2500): G_Loss: 2.1622
# ===> Epoch(1044/2500): G_Loss: 2.5249
# ===> Epoch(1045/2500): G_Loss: 2.7561
# ===> Epoch(1046/2500): G_Loss: 1.6221
# ===> Epoch(1047/2500): G_Loss: 2.3074
# ===> Epoch(1048/2500): G_Loss: 2.3703
# ===> Epoch(1049/2500): G_Loss: 2.7518
# ===> Epoch(1050/2500): G_Loss: 2.0236
# ===> Epoch(1051/2500): G_Loss: 2.3603
# ===> Epoch(1052/2500): G_Loss: 1.9992
# ===> Epoch(1053/2500): G_Loss: 3.1554
# ===> Epoch(1054/2500): G_Loss: 2.2251
# ===> Epoch(1055/2500): G_Loss: 1.9720
# ===> Epoch(1056/2500): G_Loss: 2.6068
# ===> Epoch(1057/2500): G_Loss: 2.3291
# ===> Epoch(1058/2500): G_Loss: 2.2456
# ===> Epoch(1059/2500): G_Loss: 2.0238
# ===> Epoch(1060/2500): G_Loss: 2.8594
# ===> Epoch(1061/2500): G_Loss: 2.8870
# ===> Epoch(1062/2500): G_Loss: 2.7285
# ===> Epoch(1063/2500): G_Loss: 2.5876
# ===> Epoch(1064/2500): G_Loss: 3.5866
# ===> Epoch(1065/2500): G_Loss: 2.9933
# ===> Epoch(1066/2500): G_Loss: 2.3651
# ===> Epoch(1067/2500): G_Loss: 4.4806
# ===> Epoch(1068/2500): G_Loss: 2.6869
# ===> Epoch(1069/2500): G_Loss: 2.2463
# ===> Epoch(1070/2500): G_Loss: 2.2076
# ===> Epoch(1071/2500): G_Loss: 3.9516
# ===> Epoch(1072/2500): G_Loss: 2.4452
# ===> Epoch(1073/2500): G_Loss: 1.8585
# ===> Epoch(1074/2500): G_Loss: 3.0523
# ===> Epoch(1075/2500): G_Loss: 2.3583
# ===> Epoch(1076/2500): G_Loss: 2.1052
# ===> Epoch(1077/2500): G_Loss: 2.1818
# ===> Epoch(1078/2500): G_Loss: 1.8941
# ===> Epoch(1079/2500): G_Loss: 2.3575
# ===> Epoch(1080/2500): G_Loss: 2.7479
# ===> Epoch(1081/2500): G_Loss: 2.0101
# ===> Epoch(1082/2500): G_Loss: 2.3809
# ===> Epoch(1083/2500): G_Loss: 2.3085
# ===> Epoch(1084/2500): G_Loss: 2.7704
# ===> Epoch(1085/2500): G_Loss: 3.1974
# ===> Epoch(1086/2500): G_Loss: 2.1095
# ===> Epoch(1087/2500): G_Loss: 1.9851
# ===> Epoch(1088/2500): G_Loss: 2.6980
# ===> Epoch(1089/2500): G_Loss: 2.2496
# ===> Epoch(1090/2500): G_Loss: 2.3100
# ===> Epoch(1091/2500): G_Loss: 2.1909
# ===> Epoch(1092/2500): G_Loss: 2.5010
# ===> Epoch(1093/2500): G_Loss: 2.8035
# ===> Epoch(1094/2500): G_Loss: 2.2355
# ...
# ===> Epoch(2091/2500): G_Loss: 1.4111
# ===> Epoch(2092/2500): G_Loss: 1.6605
# ===> Epoch(2093/2500): G_Loss: 1.3368
# ===> Epoch(2094/2500): G_Loss: 1.7336
# ===> Epoch(2095/2500): G_Loss: 0.9626
# ===> Epoch(2096/2500): G_Loss: 1.8303
# ===> Epoch(2097/2500): G_Loss: 1.3293
# ===> Epoch(2098/2500): G_Loss: 1.5776
# ===> Epoch(2099/2500): G_Loss: 1.1420
# ===> Epoch(2100/2500): G_Loss: 1.3738
# ===> Epoch(2101/2500): G_Loss: 1.4853
# ===> Epoch(2102/2500): G_Loss: 2.8966
# ===> Epoch(2103/2500): G_Loss: 1.4709
# ===> Epoch(2104/2500): G_Loss: 1.6882
# ===> Epoch(2105/2500): G_Loss: 1.7220
# ===> Epoch(2106/2500): G_Loss: 1.2011
# ===> Epoch(2107/2500): G_Loss: 1.2852
# ===> Epoch(2108/2500): G_Loss: 2.1318
# ===> Epoch(2109/2500): G_Loss: 1.3519
# ===> Epoch(2110/2500): G_Loss: 2.1436
# ===> Epoch(2111/2500): G_Loss: 1.5475
# ===> Epoch(2112/2500): G_Loss: 1.8691
# ===> Epoch(2113/2500): G_Loss: 1.8994
# ===> Epoch(2114/2500): G_Loss: 1.5257
# ===> Epoch(2115/2500): G_Loss: 1.2878
# ===> Epoch(2116/2500): G_Loss: 1.7269
# ===> Epoch(2117/2500): G_Loss: 1.9395
# ===> Epoch(2118/2500): G_Loss: 2.1628
# ===> Epoch(2119/2500): G_Loss: 1.0475
# ===> Epoch(2120/2500): G_Loss: 1.1606
# ===> Epoch(2121/2500): G_Loss: 1.7356
# ===> Epoch(2122/2500): G_Loss: 1.1320
# ===> Epoch(2123/2500): G_Loss: 2.0087
# ===> Epoch(2124/2500): G_Loss: 1.3621
# ===> Epoch(2125/2500): G_Loss: 1.4964
# ===> Epoch(2126/2500): G_Loss: 2.0314
# ===> Epoch(2127/2500): G_Loss: 1.3828
# ===> Epoch(2128/2500): G_Loss: 1.4529
# ===> Epoch(2129/2500): G_Loss: 2.4764
# ===> Epoch(2130/2500): G_Loss: 1.3208
# ===> Epoch(2131/2500): G_Loss: 1.0270
# ===> Epoch(2132/2500): G_Loss: 1.2870
# ===> Epoch(2133/2500): G_Loss: 1.9089
# ===> Epoch(2134/2500): G_Loss: 1.5058
# ===> Epoch(2135/2500): G_Loss: 1.3360
# ===> Epoch(2136/2500): G_Loss: 1.2618
# ===> Epoch(2137/2500): G_Loss: 1.5037
# ===> Epoch(2138/2500): G_Loss: 1.2577
# ===> Epoch(2139/2500): G_Loss: 1.1630
# ===> Epoch(2140/2500): G_Loss: 1.4909
# ===> Epoch(2141/2500): G_Loss: 2.1723
# ===> Epoch(2142/2500): G_Loss: 1.6100
# ===> Epoch(2143/2500): G_Loss: 3.2309
# ===> Epoch(2144/2500): G_Loss: 1.5853
# ===> Epoch(2145/2500): G_Loss: 2.0307
# ===> Epoch(2146/2500): G_Loss: 3.3862
# ===> Epoch(2147/2500): G_Loss: 2.0523
# ===> Epoch(2148/2500): G_Loss: 1.5430
# ===> Epoch(2149/2500): G_Loss: 1.9433
# ===> Epoch(2150/2500): G_Loss: 3.3108
# ===> Epoch(2151/2500): G_Loss: 1.8688
# ===> Epoch(2152/2500): G_Loss: 2.0746
# ===> Epoch(2153/2500): G_Loss: 1.6177
# ===> Epoch(2154/2500): G_Loss: 1.6546
# ===> Epoch(2155/2500): G_Loss: 1.5437
# ===> Epoch(2156/2500): G_Loss: 1.5941
# ===> Epoch(2157/2500): G_Loss: 1.4423
# ===> Epoch(2158/2500): G_Loss: 1.4559
# ===> Epoch(2159/2500): G_Loss: 1.2136
# ===> Epoch(2160/2500): G_Loss: 0.9923
# ===> Epoch(2161/2500): G_Loss: 1.1457
# ===> Epoch(2162/2500): G_Loss: 0.9815
# ===> Epoch(2163/2500): G_Loss: 1.3965
# ===> Epoch(2164/2500): G_Loss: 1.1055
# ===> Epoch(2165/2500): G_Loss: 0.9509
# ===> Epoch(2166/2500): G_Loss: 1.0385
# ===> Epoch(2167/2500): G_Loss: 1.3908
# ===> Epoch(2168/2500): G_Loss: 1.2549
# ===> Epoch(2169/2500): G_Loss: 1.3382
# ===> Epoch(2170/2500): G_Loss: 1.3813
# ===> Epoch(2171/2500): G_Loss: 1.1085
# ===> Epoch(2172/2500): G_Loss: 1.2743
# ===> Epoch(2173/2500): G_Loss: 1.2170
# ===> Epoch(2174/2500): G_Loss: 1.1363
# ===> Epoch(2175/2500): G_Loss: 1.2733
# ===> Epoch(2176/2500): G_Loss: 1.1547
# ===> Epoch(2177/2500): G_Loss: 1.4213
# ===> Epoch(2178/2500): G_Loss: 1.1980
# ===> Epoch(2179/2500): G_Loss: 1.4241
# ===> Epoch(2180/2500): G_Loss: 1.1579
# ===> Epoch(2181/2500): G_Loss: 1.2256
# ===> Epoch(2182/2500): G_Loss: 1.1530
# ===> Epoch(2183/2500): G_Loss: 1.3478
# ===> Epoch(2184/2500): G_Loss: 1.8480
# ===> Epoch(2185/2500): G_Loss: 2.1950
# ===> Epoch(2186/2500): G_Loss: 1.8040
# ===> Epoch(2187/2500): G_Loss: 1.5377
# ===> Epoch(2188/2500): G_Loss: 1.7022
# ===> Epoch(2189/2500): G_Loss: 1.6177
# ===> Epoch(2190/2500): G_Loss: 1.8581
# ===> Epoch(2191/2500): G_Loss: 1.6238
# ===> Epoch(2192/2500): G_Loss: 2.2161
# ===> Epoch(2193/2500): G_Loss: 2.1983
# ===> Epoch(2194/2500): G_Loss: 1.5752
# ===> Epoch(2195/2500): G_Loss: 2.7730
# ===> Epoch(2196/2500): G_Loss: 2.0713
# ===> Epoch(2197/2500): G_Loss: 1.2402
# ===> Epoch(2198/2500): G_Loss: 1.2488
# ===> Epoch(2199/2500): G_Loss: 1.8338
# ===> Epoch(2200/2500): G_Loss: 2.2585
# ===> Epoch(2201/2500): G_Loss: 1.6720
# ===> Epoch(2202/2500): G_Loss: 1.3643
# ===> Epoch(2203/2500): G_Loss: 1.0825
# ===> Epoch(2204/2500): G_Loss: 1.6401
# ===> Epoch(2205/2500): G_Loss: 1.5381
# ===> Epoch(2206/2500): G_Loss: 1.4363
# ===> Epoch(2207/2500): G_Loss: 1.7042
# ===> Epoch(2208/2500): G_Loss: 1.1693
# ===> Epoch(2209/2500): G_Loss: 1.1262
# ===> Epoch(2210/2500): G_Loss: 1.7672
# ===> Epoch(2211/2500): G_Loss: 1.5106
# ===> Epoch(2212/2500): G_Loss: 1.8456
# ===> Epoch(2213/2500): G_Loss: 1.1681
# ===> Epoch(2214/2500): G_Loss: 1.5357
# ===> Epoch(2215/2500): G_Loss: 2.6318
# ===> Epoch(2216/2500): G_Loss: 1.0046
# ===> Epoch(2217/2500): G_Loss: 1.1246
# ===> Epoch(2218/2500): G_Loss: 1.5389
# ===> Epoch(2219/2500): G_Loss: 1.5689
# ===> Epoch(2220/2500): G_Loss: 1.4756
# ===> Epoch(2221/2500): G_Loss: 1.4905
# ===> Epoch(2222/2500): G_Loss: 1.4930
# ===> Epoch(2223/2500): G_Loss: 1.4777
# ===> Epoch(2224/2500): G_Loss: 1.1643
# ===> Epoch(2225/2500): G_Loss: 1.2203
# ===> Epoch(2226/2500): G_Loss: 1.3296
# ===> Epoch(2227/2500): G_Loss: 1.5699
# ===> Epoch(2228/2500): G_Loss: 1.3444
# ===> Epoch(2229/2500): G_Loss: 1.2096
# ===> Epoch(2230/2500): G_Loss: 1.3644
# ===> Epoch(2231/2500): G_Loss: 1.3949
# ===> Epoch(2232/2500): G_Loss: 1.1419
# ===> Epoch(2233/2500): G_Loss: 1.3793
# ===> Epoch(2234/2500): G_Loss: 1.5515
# ===> Epoch(2235/2500): G_Loss: 1.4966
# ===> Epoch(2236/2500): G_Loss: 1.0869
# ===> Epoch(2237/2500): G_Loss: 0.9383
# ===> Epoch(2238/2500): G_Loss: 1.0373
# ===> Epoch(2239/2500): G_Loss: 1.5128
# ===> Epoch(2240/2500): G_Loss: 1.2625
# ===> Epoch(2241/2500): G_Loss: 1.1527
# ===> Epoch(2242/2500): G_Loss: 1.2170
# ===> Epoch(2243/2500): G_Loss: 1.1370
# ===> Epoch(2244/2500): G_Loss: 1.2081
# ===> Epoch(2245/2500): G_Loss: 1.2147
# ===> Epoch(2246/2500): G_Loss: 1.1075
# ===> Epoch(2247/2500): G_Loss: 1.1017
# ===> Epoch(2248/2500): G_Loss: 1.1921
# ===> Epoch(2249/2500): G_Loss: 1.4102
# ===> Epoch(2250/2500): G_Loss: 1.2920
# ===> Epoch(2251/2500): G_Loss: 1.2748
# ===> Epoch(2252/2500): G_Loss: 0.9683
# ===> Epoch(2253/2500): G_Loss: 1.1049
# ===> Epoch(2254/2500): G_Loss: 1.3748
# ===> Epoch(2255/2500): G_Loss: 1.2901
# ===> Epoch(2256/2500): G_Loss: 2.1259
# ===> Epoch(2257/2500): G_Loss: 1.1561
# ===> Epoch(2258/2500): G_Loss: 1.6423
# ===> Epoch(2259/2500): G_Loss: 1.5141
# ===> Epoch(2260/2500): G_Loss: 1.3898
# ===> Epoch(2261/2500): G_Loss: 1.1457
# ===> Epoch(2262/2500): G_Loss: 1.8531
# ===> Epoch(2263/2500): G_Loss: 0.9570
# ===> Epoch(2264/2500): G_Loss: 1.1987
# ===> Epoch(2265/2500): G_Loss: 1.1047
# ===> Epoch(2266/2500): G_Loss: 1.6029
# ===> Epoch(2267/2500): G_Loss: 1.4668
# ===> Epoch(2268/2500): G_Loss: 1.2670
# ===> Epoch(2269/2500): G_Loss: 1.1931
# ===> Epoch(2270/2500): G_Loss: 2.2185
# ===> Epoch(2271/2500): G_Loss: 1.3568
# ===> Epoch(2272/2500): G_Loss: 0.9434
# ===> Epoch(2273/2500): G_Loss: 1.4494
# ===> Epoch(2274/2500): G_Loss: 1.4470
# ===> Epoch(2275/2500): G_Loss: 1.1750
# ===> Epoch(2276/2500): G_Loss: 1.0425
# ===> Epoch(2277/2500): G_Loss: 1.2656
# ===> Epoch(2278/2500): G_Loss: 1.9174
# ===> Epoch(2279/2500): G_Loss: 1.1126
# ===> Epoch(2280/2500): G_Loss: 1.2181
# ===> Epoch(2281/2500): G_Loss: 1.2815
# ===> Epoch(2282/2500): G_Loss: 1.2526
# ===> Epoch(2283/2500): G_Loss: 1.7338
# ===> Epoch(2284/2500): G_Loss: 1.0589
# ===> Epoch(2285/2500): G_Loss: 1.1908
# ===> Epoch(2286/2500): G_Loss: 1.7818
# ===> Epoch(2287/2500): G_Loss: 1.5057
# ===> Epoch(2288/2500): G_Loss: 1.1071
# ===> Epoch(2289/2500): G_Loss: 1.1119
# ===> Epoch(2290/2500): G_Loss: 1.2195
# ===> Epoch(2291/2500): G_Loss: 1.8240
# ===> Epoch(2292/2500): G_Loss: 1.8788
# ===> Epoch(2293/2500): G_Loss: 1.1629
# ===> Epoch(2294/2500): G_Loss: 1.3223
# ===> Epoch(2295/2500): G_Loss: 2.1027
# ===> Epoch(2296/2500): G_Loss: 1.4677
# ===> Epoch(2297/2500): G_Loss: 1.0429
# ===> Epoch(2298/2500): G_Loss: 1.8569
# ===> Epoch(2299/2500): G_Loss: 2.5669
# ===> Epoch(2300/2500): G_Loss: 1.4303
# ===> Epoch(2301/2500): G_Loss: 1.0868
# ===> Epoch(2302/2500): G_Loss: 1.6697
# ===> Epoch(2303/2500): G_Loss: 1.3707
# ===> Epoch(2304/2500): G_Loss: 1.1738
# ===> Epoch(2305/2500): G_Loss: 1.1761
# ===> Epoch(2306/2500): G_Loss: 1.5406
# ===> Epoch(2307/2500): G_Loss: 1.6323
# ===> Epoch(2308/2500): G_Loss: 1.5037
# ===> Epoch(2309/2500): G_Loss: 1.0820
# ===> Epoch(2310/2500): G_Loss: 1.0017
# ===> Epoch(2311/2500): G_Loss: 1.1869
# ===> Epoch(2312/2500): G_Loss: 1.4719
# ===> Epoch(2313/2500): G_Loss: 1.4146
# ===> Epoch(2314/2500): G_Loss: 1.2028
# ===> Epoch(2315/2500): G_Loss: 1.3989
# ===> Epoch(2316/2500): G_Loss: 1.7264
# ===> Epoch(2317/2500): G_Loss: 1.0574
# ===> Epoch(2318/2500): G_Loss: 1.0320
# ===> Epoch(2319/2500): G_Loss: 1.6511
# ===> Epoch(2320/2500): G_Loss: 1.9286
# ===> Epoch(2321/2500): G_Loss: 1.5673
# ===> Epoch(2322/2500): G_Loss: 2.8856
# ===> Epoch(2323/2500): G_Loss: 1.4812
# ===> Epoch(2324/2500): G_Loss: 1.3625
# ===> Epoch(2325/2500): G_Loss: 1.3320
# ===> Epoch(2326/2500): G_Loss: 1.3283
# ===> Epoch(2327/2500): G_Loss: 1.0383
# ===> Epoch(2328/2500): G_Loss: 1.3946
# ===> Epoch(2329/2500): G_Loss: 1.2164
# ===> Epoch(2330/2500): G_Loss: 1.3034
# ===> Epoch(2331/2500): G_Loss: 1.5297
# ===> Epoch(2332/2500): G_Loss: 1.3859
# ===> Epoch(2333/2500): G_Loss: 1.0234
# ===> Epoch(2334/2500): G_Loss: 0.9619
# ===> Epoch(2335/2500): G_Loss: 1.8594
# ===> Epoch(2336/2500): G_Loss: 1.3167
# ===> Epoch(2337/2500): G_Loss: 0.9815
# ===> Epoch(2338/2500): G_Loss: 1.3599
# ===> Epoch(2339/2500): G_Loss: 1.2228
# ===> Epoch(2340/2500): G_Loss: 1.1980
# ===> Epoch(2341/2500): G_Loss: 1.4993
# ===> Epoch(2342/2500): G_Loss: 1.0302
# ===> Epoch(2343/2500): G_Loss: 1.1205
# ===> Epoch(2344/2500): G_Loss: 1.0831
# ===> Epoch(2345/2500): G_Loss: 1.2635
# ===> Epoch(2346/2500): G_Loss: 0.8748
# ===> Epoch(2347/2500): G_Loss: 1.0072
# ===> Epoch(2348/2500): G_Loss: 1.2293
# ===> Epoch(2349/2500): G_Loss: 1.4901
# ===> Epoch(2350/2500): G_Loss: 1.5998
# ===> Epoch(2351/2500): G_Loss: 1.2718
# ===> Epoch(2352/2500): G_Loss: 1.0728
# ===> Epoch(2353/2500): G_Loss: 1.4124
# ===> Epoch(2354/2500): G_Loss: 1.0848
# ===> Epoch(2355/2500): G_Loss: 1.7451
# ===> Epoch(2356/2500): G_Loss: 1.3237
# ===> Epoch(2357/2500): G_Loss: 1.2420
# ===> Epoch(2358/2500): G_Loss: 1.2343
# ===> Epoch(2359/2500): G_Loss: 2.3231
# ===> Epoch(2360/2500): G_Loss: 1.2322
# ===> Epoch(2361/2500): G_Loss: 1.0588
# ===> Epoch(2362/2500): G_Loss: 1.5319
# ===> Epoch(2363/2500): G_Loss: 1.4144
# ===> Epoch(2364/2500): G_Loss: 1.9223
# ===> Epoch(2365/2500): G_Loss: 1.0636
# ===> Epoch(2366/2500): G_Loss: 1.6791
# ===> Epoch(2367/2500): G_Loss: 1.1034
# ===> Epoch(2368/2500): G_Loss: 1.1320
# ===> Epoch(2369/2500): G_Loss: 1.2683
# ===> Epoch(2370/2500): G_Loss: 1.4405
# ===> Epoch(2371/2500): G_Loss: 1.2516
# ===> Epoch(2372/2500): G_Loss: 1.2913
# ===> Epoch(2373/2500): G_Loss: 1.2355
# ===> Epoch(2374/2500): G_Loss: 1.3356
# ===> Epoch(2375/2500): G_Loss: 1.1553
# ===> Epoch(2376/2500): G_Loss: 1.4708
# ===> Epoch(2377/2500): G_Loss: 1.2539
# ===> Epoch(2378/2500): G_Loss: 1.1650
# ===> Epoch(2379/2500): G_Loss: 1.4595
# ===> Epoch(2380/2500): G_Loss: 1.3557
# ===> Epoch(2381/2500): G_Loss: 1.1332
# ===> Epoch(2382/2500): G_Loss: 1.4930
# ===> Epoch(2383/2500): G_Loss: 1.0661
# ===> Epoch(2384/2500): G_Loss: 1.3019
# ===> Epoch(2385/2500): G_Loss: 1.7181
# ===> Epoch(2386/2500): G_Loss: 1.0721
# ===> Epoch(2387/2500): G_Loss: 1.3024
# ===> Epoch(2388/2500): G_Loss: 1.0175
# ===> Epoch(2389/2500): G_Loss: 1.4526
# ===> Epoch(2390/2500): G_Loss: 1.1986
# ===> Epoch(2391/2500): G_Loss: 1.2696
# ===> Epoch(2392/2500): G_Loss: 0.9992
# ===> Epoch(2393/2500): G_Loss: 1.1194
# ===> Epoch(2394/2500): G_Loss: 1.4973
# ===> Epoch(2395/2500): G_Loss: 1.0594
# ===> Epoch(2396/2500): G_Loss: 1.2808
# ===> Epoch(2397/2500): G_Loss: 1.3312
# ===> Epoch(2398/2500): G_Loss: 1.3790
# ===> Epoch(2399/2500): G_Loss: 1.0885
# ===> Epoch(2400/2500): G_Loss: 1.5270
# ===> Epoch(2401/2500): G_Loss: 1.2930
# ===> Epoch(2402/2500): G_Loss: 1.6387
# ===> Epoch(2403/2500): G_Loss: 1.4404
# ===> Epoch(2404/2500): G_Loss: 1.3307
# ===> Epoch(2405/2500): G_Loss: 1.1511
# ===> Epoch(2406/2500): G_Loss: 0.9484
# ===> Epoch(2407/2500): G_Loss: 1.7096
# ===> Epoch(2408/2500): G_Loss: 1.2435
# ===> Epoch(2409/2500): G_Loss: 1.8640
# ===> Epoch(2410/2500): G_Loss: 1.1650
# ===> Epoch(2411/2500): G_Loss: 1.1342
# ===> Epoch(2412/2500): G_Loss: 1.3812
# ===> Epoch(2413/2500): G_Loss: 1.2721
# ===> Epoch(2414/2500): G_Loss: 1.6431
# ===> Epoch(2415/2500): G_Loss: 1.0828
# ===> Epoch(2416/2500): G_Loss: 1.2583
# ===> Epoch(2417/2500): G_Loss: 1.6135
# ===> Epoch(2418/2500): G_Loss: 2.3680
# ===> Epoch(2419/2500): G_Loss: 1.1618
# ===> Epoch(2420/2500): G_Loss: 1.3247
# ===> Epoch(2421/2500): G_Loss: 1.3581
# ===> Epoch(2422/2500): G_Loss: 1.6952
# ===> Epoch(2423/2500): G_Loss: 1.0998
# ===> Epoch(2424/2500): G_Loss: 1.3105
# ===> Epoch(2425/2500): G_Loss: 2.1747
# ===> Epoch(2426/2500): G_Loss: 1.0052
# ===> Epoch(2427/2500): G_Loss: 1.3834
# ===> Epoch(2428/2500): G_Loss: 1.4068
# ===> Epoch(2429/2500): G_Loss: 1.2844
# ===> Epoch(2430/2500): G_Loss: 1.3057
# ===> Epoch(2431/2500): G_Loss: 1.2245
# ===> Epoch(2432/2500): G_Loss: 1.0572
# ===> Epoch(2433/2500): G_Loss: 1.6778
# ===> Epoch(2434/2500): G_Loss: 1.4362
# ===> Epoch(2435/2500): G_Loss: 1.3229
# ===> Epoch(2436/2500): G_Loss: 1.1461
# ===> Epoch(2437/2500): G_Loss: 1.1041
# ===> Epoch(2438/2500): G_Loss: 0.9962
# ===> Epoch(2439/2500): G_Loss: 1.1352
# ===> Epoch(2440/2500): G_Loss: 1.0247
# ===> Epoch(2441/2500): G_Loss: 1.7660
# ===> Epoch(2442/2500): G_Loss: 0.9694
# ===> Epoch(2443/2500): G_Loss: 1.3040
# ===> Epoch(2444/2500): G_Loss: 1.1773
# ===> Epoch(2445/2500): G_Loss: 1.3075
# ===> Epoch(2446/2500): G_Loss: 1.3081
# ===> Epoch(2447/2500): G_Loss: 1.1611
# ===> Epoch(2448/2500): G_Loss: 1.2531
# ===> Epoch(2449/2500): G_Loss: 1.3212
# ===> Epoch(2450/2500): G_Loss: 1.6857
# ===> Epoch(2451/2500): G_Loss: 1.0805
# ===> Epoch(2452/2500): G_Loss: 1.0116
# ===> Epoch(2453/2500): G_Loss: 0.8499
# ===> Epoch(2454/2500): G_Loss: 1.1991
# ===> Epoch(2455/2500): G_Loss: 1.4820
# ===> Epoch(2456/2500): G_Loss: 1.4344
# ===> Epoch(2457/2500): G_Loss: 1.2954
# ===> Epoch(2458/2500): G_Loss: 1.3897
# ===> Epoch(2459/2500): G_Loss: 1.2949
# ===> Epoch(2460/2500): G_Loss: 1.5624
# ===> Epoch(2461/2500): G_Loss: 1.2400
# ===> Epoch(2462/2500): G_Loss: 0.9420
# ===> Epoch(2463/2500): G_Loss: 0.8557
# ===> Epoch(2464/2500): G_Loss: 1.0716
# ===> Epoch(2465/2500): G_Loss: 1.1807
# ===> Epoch(2466/2500): G_Loss: 1.2718
# ===> Epoch(2467/2500): G_Loss: 1.2420
# ===> Epoch(2468/2500): G_Loss: 0.9924
# ===> Epoch(2469/2500): G_Loss: 1.6304
# ===> Epoch(2470/2500): G_Loss: 1.3023
# ===> Epoch(2471/2500): G_Loss: 1.1991
# ===> Epoch(2472/2500): G_Loss: 1.1885
# ===> Epoch(2473/2500): G_Loss: 2.2655
# ===> Epoch(2474/2500): G_Loss: 1.9088
# ===> Epoch(2475/2500): G_Loss: 1.1443
# ===> Epoch(2476/2500): G_Loss: 1.7249
# ===> Epoch(2477/2500): G_Loss: 1.1745
# ===> Epoch(2478/2500): G_Loss: 1.0161
# ===> Epoch(2479/2500): G_Loss: 1.2472
# ===> Epoch(2480/2500): G_Loss: 1.4609
# ===> Epoch(2481/2500): G_Loss: 1.0349
# ===> Epoch(2482/2500): G_Loss: 1.0546
# ===> Epoch(2483/2500): G_Loss: 1.1263
# ===> Epoch(2484/2500): G_Loss: 1.0839
# ===> Epoch(2485/2500): G_Loss: 0.9892
# ===> Epoch(2486/2500): G_Loss: 1.0455
# ===> Epoch(2487/2500): G_Loss: 1.3228
# ===> Epoch(2488/2500): G_Loss: 1.1571
# ===> Epoch(2489/2500): G_Loss: 1.6075
# ===> Epoch(2490/2500): G_Loss: 1.0108
# ===> Epoch(2491/2500): G_Loss: 1.2513
# ===> Epoch(2492/2500): G_Loss: 1.2250
# ===> Epoch(2493/2500): G_Loss: 1.6029
# ===> Epoch(2494/2500): G_Loss: 1.1097
# ===> Epoch(2495/2500): G_Loss: 1.1970
# ===> Epoch(2496/2500): G_Loss: 1.0897
# ===> Epoch(2497/2500): G_Loss: 1.0620
# ===> Epoch(2498/2500): G_Loss: 2.0957
# ===> Epoch(2499/2500): G_Loss: 1.0219
# ===> Epoch(2500/2500): G_Loss: 1.0373
